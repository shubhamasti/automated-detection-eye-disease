# %% [markdown]
# ## Segment Retinal Atrophy

# %% [markdown]
# ### UNET model

# %%
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import layers, models

from sklearn.model_selection import train_test_split

# %%
def load_data(image_dir, mask_dir, image_size):
    images = []
    masks = []
    
    # Loop through all image files
    for filename in os.listdir(image_dir):
        if filename.endswith(".jpg"):
            # Get the base name (e.g., 'H0001' from 'H0001.jpg')
            base_name = os.path.splitext(filename)[0]
            
            # Construct the corresponding mask filename
            mask_filename = f"{base_name}.bmp"
            
            # Check if the corresponding mask exists
            img_path = os.path.join(image_dir, filename)
            mask_path = os.path.join(mask_dir, mask_filename)
        
            if os.path.exists(mask_path):
                # Load and resize the image and mask
                img = load_img(img_path, target_size=image_size)
                mask = load_img(mask_path, target_size=image_size, color_mode="grayscale")
                
                # Convert to numpy arrays
                img_array = img_to_array(img) / 255.0  # Normalize the image between 0 and 1
                mask_array = img_to_array(mask) / 255.0  # Mask is binary
                
                # Append the arrays to the lists
                images.append(img_array)
                masks.append(mask_array)
            else:
                print(f"Skipping {filename} as no corresponding mask was found.")
    
    # Convert the lists to numpy arrays
    return np.array(images), np.array(masks)

def unet_model(input_size=(256, 256, 3)):
    inputs = layers.Input(input_size)
    
    # Encoder
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Bottleneck
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv3)
    
    # Decoder
    up1 = layers.UpSampling2D(size=(2, 2))(conv3)
    up1 = layers.concatenate([up1, conv2], axis=-1)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(up1)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv4)
    
    up2 = layers.UpSampling2D(size=(2, 2))(conv4)
    up2 = layers.concatenate([up2, conv1], axis=-1)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(up2)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv5)
    
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv5)  # Sigmoid for binary classification
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
model = unet_model(input_size=(256, 256, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2024-09-25 23:22:59.129998: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-25 23:22:59.130269: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M2 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 128, 128, 25  0           ['conv2d_5[0][0]']
#                                 6)
#
#  concatenate (Concatenate)      (None, 128, 128, 38  0           ['up_sampling2d[0][0]',
#                                 4)                                'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 12  442496      ['concatenate[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_6[0][0]']
#                                 8)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_7[0][0]']
#                                 8)
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_1[0][0]',
#                                 2)                                'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 64  110656      ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 1)  65          ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 1,883,137
# Trainable params: 1,883,137
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Directories for images and masks
image_dir = 'path/to/images'
mask_dir = 'path/to/atrophy_masks'

# Image size (height, width, channels)
image_size = (256, 256)

all_images, all_masks = load_data(image_dir, mask_dir, image_size)

# Split into training and test sets (80% train, 20% test)
train_images, test_images, train_masks, test_masks = train_test_split(
    all_images, all_masks, test_size=0.2, random_state=42
)

# split train set into training and validation sets (90% train, 10% validation)
train_images, val_images, train_masks, val_masks = train_test_split(
    train_images, train_masks, test_size=0.1, random_state=42
)
# Out:
# Skipping N0010.jpg as no corresponding mask was found.
# Skipping T0042.jpg as no corresponding mask was found.
# Skipping V0379.jpg as no corresponding mask was found.
# Skipping V0345.jpg as no corresponding mask was found.
# Skipping T0254.jpg as no corresponding mask was found.
# Skipping V0190.jpg as no corresponding mask was found.
# Skipping V0147.jpg as no corresponding mask was found.
# Skipping T0283.jpg as no corresponding mask was found.
# Skipping P0076.jpg as no corresponding mask was found.
# Skipping T0334.jpg as no corresponding mask was found.
# Skipping N0158.jpg as no corresponding mask was found.
# Skipping V0231.jpg as no corresponding mask was found.
# Skipping V0225.jpg as no corresponding mask was found.
# Skipping V0032.jpg as no corresponding mask was found.
# Skipping T0335.jpg as no corresponding mask was found.
# Skipping T0309.jpg as no corresponding mask was found.
# Skipping T0296.jpg as no corresponding mask was found.
# Skipping T0269.jpg as no corresponding mask was found.
# Skipping V0350.jpg as no corresponding mask was found.
# Skipping V0393.jpg as no corresponding mask was found.
# Skipping N0039.jpg as no corresponding mask was found.
# Skipping T0057.jpg as no corresponding mask was found.
# Skipping N0013.jpg as no corresponding mask was found.
# Skipping V0391.jpg as no corresponding mask was found.
# Skipping V0346.jpg as no corresponding mask was found.
# Skipping T0257.jpg as no corresponding mask was found.
# Skipping V0187.jpg as no corresponding mask was found.
# Skipping T0294.jpg as no corresponding mask was found.
# Skipping T0323.jpg as no corresponding mask was found.
# Skipping V0018.jpg as no corresponding mask was found.
# Skipping V0024.jpg as no corresponding mask was found.
# Skipping T0121.jpg as no corresponding mask was found.
# Skipping V0232.jpg as no corresponding mask was found.
# Skipping V0227.jpg as no corresponding mask was found.
# Skipping T0108.jpg as no corresponding mask was found.
# Skipping V0031.jpg as no corresponding mask was found.
# Skipping V0145.jpg as no corresponding mask was found.
# Skipping T0295.jpg as no corresponding mask was found.
# Skipping V0151.jpg as no corresponding mask was found.
# Skipping T0083.jpg as no corresponding mask was found.
# Skipping T0040.jpg as no corresponding mask was found.
# Skipping T0068.jpg as no corresponding mask was found.
# Skipping V0380.jpg as no corresponding mask was found.
# Skipping N0002.jpg as no corresponding mask was found.
# Skipping N0016.jpg as no corresponding mask was found.
# Skipping V0357.jpg as no corresponding mask was found.
# Skipping T0093.jpg as no corresponding mask was found.
# Skipping T0285.jpg as no corresponding mask was found.
# Skipping V0155.jpg as no corresponding mask was found.
# Skipping V0169.jpg as no corresponding mask was found.
# Skipping P0070.jpg as no corresponding mask was found.
# Skipping T0119.jpg as no corresponding mask was found.
# Skipping T0125.jpg as no corresponding mask was found.
# Skipping T0333.jpg as no corresponding mask was found.
# Skipping T0290.jpg as no corresponding mask was found.
# Skipping V0154.jpg as no corresponding mask was found.
# Skipping T0284.jpg as no corresponding mask was found.
# Skipping V0183.jpg as no corresponding mask was found.
# Skipping V0197.jpg as no corresponding mask was found.
# Skipping T0247.jpg as no corresponding mask was found.
# Skipping N0017.jpg as no corresponding mask was found.
# Skipping N0003.jpg as no corresponding mask was found.
# Skipping H0007.jpg as no corresponding mask was found.
# Skipping N0042.jpg as no corresponding mask was found.
# Skipping N0056.jpg as no corresponding mask was found.
# Skipping N0031.jpg as no corresponding mask was found.
# Skipping N0025.jpg as no corresponding mask was found.
# Skipping N0019.jpg as no corresponding mask was found.
# Skipping V0006.jpg as no corresponding mask was found.
# Skipping V0238.jpg as no corresponding mask was found.
# Skipping V0239.jpg as no corresponding mask was found.
# Skipping V0007.jpg as no corresponding mask was found.
# Skipping T0328.jpg as no corresponding mask was found.
# Skipping V0167.jpg as no corresponding mask was found.
# Skipping T0274.jpg as no corresponding mask was found.
# Skipping T0076.jpg as no corresponding mask was found.
# Skipping N0024.jpg as no corresponding mask was found.
# Skipping N0030.jpg as no corresponding mask was found.
# Skipping N0026.jpg as no corresponding mask was found.
# Skipping N0032.jpg as no corresponding mask was found.
# Skipping V0367.jpg as no corresponding mask was found.
# Skipping T0262.jpg as no corresponding mask was found.
# Skipping V0159.jpg as no corresponding mask was found.
# Skipping T0302.jpg as no corresponding mask was found.
# Skipping V0039.jpg as no corresponding mask was found.
# Skipping V0005.jpg as no corresponding mask was found.
# Skipping T0128.jpg as no corresponding mask was found.
# Skipping N0147.jpg as no corresponding mask was found.
# Skipping T0129.jpg as no corresponding mask was found.
# Skipping V0010.jpg as no corresponding mask was found.
# Skipping V0004.jpg as no corresponding mask was found.
# Skipping V0164.jpg as no corresponding mask was found.
# Skipping T0277.jpg as no corresponding mask was found.
# Skipping V0400.jpg as no corresponding mask was found.
# Skipping V0372.jpg as no corresponding mask was found.
# Skipping T0049.jpg as no corresponding mask was found.
# Skipping N0033.jpg as no corresponding mask was found.
# Skipping N0027.jpg as no corresponding mask was found.
# Skipping N0037.jpg as no corresponding mask was found.
# Skipping T0267.jpg as no corresponding mask was found.
# Skipping V0174.jpg as no corresponding mask was found.
# Skipping T0298.jpg as no corresponding mask was found.
# Skipping N0157.jpg as no corresponding mask was found.
# Skipping V0202.jpg as no corresponding mask was found.
# Skipping V0217.jpg as no corresponding mask was found.
# Skipping V0203.jpg as no corresponding mask was found.
# Skipping T0104.jpg as no corresponding mask was found.
# Skipping V0015.jpg as no corresponding mask was found.
# Skipping V0001.jpg as no corresponding mask was found.
# Skipping P0078.jpg as no corresponding mask was found.
# Skipping V0175.jpg as no corresponding mask was found.
# Skipping V0363.jpg as no corresponding mask was found.
# Skipping V0377.jpg as no corresponding mask was found.
# Skipping N0036.jpg as no corresponding mask was found.
# Skipping N0022.jpg as no corresponding mask was found.
# Skipping N0034.jpg as no corresponding mask was found.
# Skipping T0099.jpg as no corresponding mask was found.
# Skipping T0304.jpg as no corresponding mask was found.
# Skipping T0112.jpg as no corresponding mask was found.
# Skipping V0229.jpg as no corresponding mask was found.
# Skipping V0200.jpg as no corresponding mask was found.
# Skipping V0214.jpg as no corresponding mask was found.
# Skipping T0339.jpg as no corresponding mask was found.
# Skipping T0259.jpg as no corresponding mask was found.
# Skipping T0265.jpg as no corresponding mask was found.
# Skipping T0098.jpg as no corresponding mask was found.
# Skipping V0348.jpg as no corresponding mask was found.
# Skipping V0360.jpg as no corresponding mask was found.

# %%
len(train_images), len(val_images), len(test_images)
# Out:
# (626, 70, 174)

# %%
history = model.fit(train_images, train_masks, epochs=50,
                    batch_size=16, verbose=1, steps_per_epoch=10,
                    validation_data=(val_images, val_masks))
# Out:
# Epoch 1/50
# 2024-09-25 23:23:26.421519: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-09-25 23:23:26.831625: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.8660
# 2024-09-25 23:23:38.460250: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 15s 1s/step - loss: 0.4589 - accuracy: 0.8660 - val_loss: 0.3182 - val_accuracy: 0.9037
# Epoch 2/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.3256 - accuracy: 0.8905 - val_loss: 0.2524 - val_accuracy: 0.9037
# Epoch 3/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.2780 - accuracy: 0.8872 - val_loss: 0.2800 - val_accuracy: 0.9037
# Epoch 4/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2491 - accuracy: 0.8882 - val_loss: 0.2855 - val_accuracy: 0.9037
# Epoch 5/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2399 - accuracy: 0.9027 - val_loss: 0.2483 - val_accuracy: 0.9037
# Epoch 6/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2395 - accuracy: 0.9047 - val_loss: 0.2170 - val_accuracy: 0.9158
# Epoch 7/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2160 - accuracy: 0.9247 - val_loss: 0.2330 - val_accuracy: 0.9032
# Epoch 8/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2408 - accuracy: 0.9088 - val_loss: 0.2059 - val_accuracy: 0.9280
# Epoch 9/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.1913 - accuracy: 0.9305 - val_loss: 0.1958 - val_accuracy: 0.9321
# Epoch 10/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.2202 - accuracy: 0.9210 - val_loss: 0.2101 - val_accuracy: 0.9243
# Epoch 11/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2188 - accuracy: 0.9223 - val_loss: 0.1935 - val_accuracy: 0.9293
# Epoch 12/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.2188 - accuracy: 0.9266 - val_loss: 0.2488 - val_accuracy: 0.8950
# Epoch 13/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2136 - accuracy: 0.9172 - val_loss: 0.2581 - val_accuracy: 0.9149
# Epoch 14/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2194 - accuracy: 0.9242 - val_loss: 0.2070 - val_accuracy: 0.9141
# Epoch 15/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2294 - accuracy: 0.9129 - val_loss: 0.2098 - val_accuracy: 0.9250
# Epoch 16/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1922 - accuracy: 0.9292 - val_loss: 0.2095 - val_accuracy: 0.9297
# Epoch 17/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1980 - accuracy: 0.9290 - val_loss: 0.1760 - val_accuracy: 0.9311
# Epoch 18/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1900 - accuracy: 0.9256 - val_loss: 0.1904 - val_accuracy: 0.9307
# Epoch 19/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1757 - accuracy: 0.9299 - val_loss: 0.1979 - val_accuracy: 0.9183
# Epoch 20/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2014 - accuracy: 0.9245 - val_loss: 0.1802 - val_accuracy: 0.9333
# Epoch 21/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1781 - accuracy: 0.9334 - val_loss: 0.1658 - val_accuracy: 0.9379
# Epoch 22/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1807 - accuracy: 0.9257 - val_loss: 0.1863 - val_accuracy: 0.9301
# Epoch 23/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1741 - accuracy: 0.9369 - val_loss: 0.1644 - val_accuracy: 0.9374
# Epoch 24/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1985 - accuracy: 0.9210 - val_loss: 0.2681 - val_accuracy: 0.9184
# Epoch 25/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2255 - accuracy: 0.9193 - val_loss: 0.2105 - val_accuracy: 0.8950
# Epoch 26/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.2112 - accuracy: 0.9232 - val_loss: 0.1913 - val_accuracy: 0.9241
# Epoch 27/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1878 - accuracy: 0.9264 - val_loss: 0.1704 - val_accuracy: 0.9290
# Epoch 28/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.1569 - accuracy: 0.9389 - val_loss: 0.1767 - val_accuracy: 0.9402
# Epoch 29/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1663 - accuracy: 0.9399 - val_loss: 0.1501 - val_accuracy: 0.9405
# Epoch 30/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1726 - accuracy: 0.9346 - val_loss: 0.1846 - val_accuracy: 0.9411
# Epoch 31/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1723 - accuracy: 0.9371 - val_loss: 0.1651 - val_accuracy: 0.9276
# Epoch 32/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.1747 - accuracy: 0.9337 - val_loss: 0.1851 - val_accuracy: 0.9192
# Epoch 33/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1668 - accuracy: 0.9347 - val_loss: 0.1647 - val_accuracy: 0.9372
# Epoch 34/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1425 - accuracy: 0.9484 - val_loss: 0.1465 - val_accuracy: 0.9449
# Epoch 35/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1588 - accuracy: 0.9408 - val_loss: 0.1432 - val_accuracy: 0.9450
# Epoch 36/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.1780 - accuracy: 0.9306 - val_loss: 0.2003 - val_accuracy: 0.9035
# Epoch 37/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1760 - accuracy: 0.9287 - val_loss: 0.1741 - val_accuracy: 0.9235
# Epoch 38/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.1511 - accuracy: 0.9411 - val_loss: 0.1749 - val_accuracy: 0.9261
# Epoch 39/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1802 - accuracy: 0.9289 - val_loss: 0.1979 - val_accuracy: 0.9187
# Epoch 40/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1799 - accuracy: 0.9306 - val_loss: 0.1544 - val_accuracy: 0.9443
# Epoch 41/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1553 - accuracy: 0.9416 - val_loss: 0.1345 - val_accuracy: 0.9466
# Epoch 42/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.1410 - accuracy: 0.9473 - val_loss: 0.1415 - val_accuracy: 0.9454
# Epoch 43/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.1432 - accuracy: 0.9444 - val_loss: 0.1501 - val_accuracy: 0.9426
# Epoch 44/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1649 - accuracy: 0.9368 - val_loss: 0.1373 - val_accuracy: 0.9452
# Epoch 45/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1622 - accuracy: 0.9368 - val_loss: 0.1464 - val_accuracy: 0.9427
# Epoch 46/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1463 - accuracy: 0.9434 - val_loss: 0.1509 - val_accuracy: 0.9398
# Epoch 47/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1537 - accuracy: 0.9450 - val_loss: 0.1474 - val_accuracy: 0.9414
# Epoch 48/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.1647 - accuracy: 0.9356 - val_loss: 0.1606 - val_accuracy: 0.9311
# Epoch 49/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1678 - accuracy: 0.9369 - val_loss: 0.1412 - val_accuracy: 0.9484
# Epoch 50/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.1508 - accuracy: 0.9417 - val_loss: 0.1359 - val_accuracy: 0.9474

# %%
scores = model.evaluate(val_images, val_masks)
print("Validation Loss: %.2f" % scores[0])
print("Validation Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 3/3 [==============================] - 2s 544ms/step - loss: 0.1359 - accuracy: 0.9474
# Validation Loss: 0.14
# Validation Accuracy: 94.74%

# %%
scores = model.evaluate(test_images, test_masks)
print("Test Loss: %.2f" % scores[0])
print("Test Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# 6/6 [==============================] - 5s 765ms/step - loss: 0.1513 - accuracy: 0.9418
# Test Loss: 0.15
# Test Accuracy: 94.18%

# %%
# Save the model
model_json = model.to_json()
with open('../features/features_segmentation.json', 'w') as json_file:
    json_file.write(model_json)

# Saving the model and weights
model.save_weights('../features_segmentation/Atrophy.weights.h5')
