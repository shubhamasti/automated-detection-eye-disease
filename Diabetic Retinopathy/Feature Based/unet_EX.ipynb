# %% [markdown]
# ## Segment Hard Exudates

# %% [markdown]
# ### UNET model

# %%
import os
import numpy as np

from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import layers, models

from sklearn.model_selection import train_test_split

# %%
def load_data(image_dir, mask_dir, image_size):
    images = []
    masks = []
    
    # Loop through all image files
    for filename in os.listdir(image_dir):
        if filename.endswith(".jpg"):
            # Get the base name (e.g., 'H0001' from 'H0001.jpg')
            base_name = os.path.splitext(filename)[0]
            
            # Construct the corresponding mask filename
            mask_filename = f"{base_name}.tif"
            
            # Check if the corresponding mask exists
            img_path = os.path.join(image_dir, filename)
            mask_path = os.path.join(mask_dir, mask_filename)
        
            if os.path.exists(mask_path):
                # Load and resize the image and mask
                img = load_img(img_path, target_size=image_size)
                mask = load_img(mask_path, target_size=image_size, color_mode="grayscale")
                
                # Convert to numpy arrays
                img_array = img_to_array(img) / 255.0  # Normalize the image between 0 and 1
                mask_array = img_to_array(mask) / 255.0  # Mask is binary
                
                if mask_array.max() <= 0:
                    print(f"Skipping {filename} as mask is empty.")
                    continue
                
                # Append the arrays to the lists
                images.append(img_array)
                masks.append(mask_array)
            else:
                print(f"Skipping {filename} as no corresponding mask was found.")
    
    # Convert the lists to numpy arrays
    return np.array(images), np.array(masks)

def unet_model(input_size=(256, 256, 3)):
    inputs = layers.Input(input_size)
    
    # Encoder
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Bottleneck
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv3)
    
    # Decoder
    up1 = layers.UpSampling2D(size=(2, 2))(conv3)
    up1 = layers.concatenate([up1, conv2], axis=-1)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(up1)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv4)
    
    up2 = layers.UpSampling2D(size=(2, 2))(conv4)
    up2 = layers.concatenate([up2, conv1], axis=-1)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(up2)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv5)
    
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv5)  # Sigmoid for binary classification
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    return model

# Dice Loss function
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return 1 - numerator / denominator

# Combined BCE and Dice Loss
def combined_bce_dice_loss(y_true, y_pred):
    bce_loss = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return bce_loss + d_loss

# using tf
def iou_metric(y_true, y_pred):
    # Convert predicted mask probabilities to binary (0 or 1)
    y_pred = tf.round(y_pred)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = intersection / (union + tf.keras.backend.epsilon())
    return iou

def dice_coefficient(y_true, y_pred):
    # Convert predicted mask probabilities to binary (0 or 1)
    y_pred = tf.round(y_pred)

    intersection = tf.reduce_sum(y_true * y_pred)
    dice = (2. * intersection) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + tf.keras.backend.epsilon())
    return dice

# %%
model = unet_model(input_size=(256, 256, 3))
model.compile(optimizer='adam', loss=combined_bce_dice_loss, metrics=['accuracy', iou_metric, dice_coefficient])
# Out:
# 2024-10-20 23:20:27.273608: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-20 23:20:27.273728: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M2 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 128, 128, 25  0           ['conv2d_5[0][0]']
#                                 6)
#
#  concatenate (Concatenate)      (None, 128, 128, 38  0           ['up_sampling2d[0][0]',
#                                 4)                                'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 12  442496      ['concatenate[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_6[0][0]']
#                                 8)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_7[0][0]']
#                                 8)
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_1[0][0]',
#                                 2)                                'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 64  110656      ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 1)  65          ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 1,883,137
# Trainable params: 1,883,137
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Directories for images and masks
image_dir = "path/to/DDR/lesion_segmentation/all/image"
mask_dir = "path/to/DDR/lesion_segmentation/all/label/EX"

# Image size (height, width, channels)
image_size = (256, 256)

all_images, all_masks = load_data(image_dir, mask_dir, image_size)
# Out:
# Skipping 007-6573-400.jpg as mask is empty.
# Skipping 007-2280-100.jpg as mask is empty.
# Skipping 007-2768-100.jpg as mask is empty.
# Skipping 007-2600-100.jpg as mask is empty.
# Skipping 007-1774-100.jpg as mask is empty.
# Skipping 007-1811-100.jpg as mask is empty.
# Skipping 20170502160732595.jpg as mask is empty.
# Skipping 007-4961-300.jpg as mask is empty.
# Skipping 007-2160-100.jpg as mask is empty.
# Skipping 007-3924-200.jpg as mask is empty.
# Skipping 007-2453-100.jpg as mask is empty.
# Skipping 007-5100-300.jpg as mask is empty.
# Skipping 007-2840-100.jpg as mask is empty.
# Skipping 20170616125321132.jpg as mask is empty.
# Skipping 007-2832-100.jpg as mask is empty.
# Skipping 20170501232731664.jpg as mask is empty.
# Skipping 007-5172-300.jpg as mask is empty.
# Skipping 007-1946-100.jpg as mask is empty.
# Skipping 007-2112-100.jpg as mask is empty.
# Skipping 007-2757-100.jpg as mask is empty.
# Skipping 20170511170800183.jpg as mask is empty.
# Skipping 007-2771-100.jpg as mask is empty.
# Skipping 007-2407-100.jpg as mask is empty.
# Skipping 007-2252-100.jpg as mask is empty.
# Skipping 007-5126-300.jpg as mask is empty.
# Skipping 007-6811-400.jpg as mask is empty.
# Skipping 20170514222317943.jpg as mask is empty.
# Skipping 007-5530-300.jpg as mask is empty.
# Skipping 20170602084034474.jpg as mask is empty.
# Skipping 007-2481-100.jpg as mask is empty.
# Skipping 007-2428-100.jpg as mask is empty.
# Skipping 007-2998-100.jpg as mask is empty.
# Skipping 007-3038-100.jpg as mask is empty.
# Skipping 007-2795-100.jpg as mask is empty.
# Skipping 007-6545-400.jpg as mask is empty.
# Skipping 007-1819-100.jpg as mask is empty.
# Skipping 007-1971-100.jpg as mask is empty.
# Skipping 20170502204843387.jpg as mask is empty.
# Skipping 007-6577-400.jpg as mask is empty.
# Skipping 007-6127-300.jpg as mask is empty.
# Skipping 007-2809-100.jpg as mask is empty.
# Skipping 007-5869-300.jpg as mask is empty.
# Skipping 007-6084-300.jpg as mask is empty.
# Skipping 007-2067-100.jpg as mask is empty.
# Skipping 007-2279-100.jpg as mask is empty.
# Skipping 007-4668-200.jpg as mask is empty.
# Skipping 20170617103821616.jpg as mask is empty.
# Skipping 007-3567-200.jpg as mask is empty.
# Skipping 007-1974-100.jpg as mask is empty.
# Skipping 007-2397-100.jpg as mask is empty.
# Skipping 20170521094903529.jpg as mask is empty.
# Skipping 20170521093537739.jpg as mask is empty.
# Skipping 20170521095717085.jpg as mask is empty.
# Skipping 007-2403-100.jpg as mask is empty.
# Skipping 007-2765-100.jpg as mask is empty.
# Skipping 007-5395-300.jpg as mask is empty.
# Skipping 007-2471-100.jpg as mask is empty.
# Skipping 007-2234-100.jpg as mask is empty.
# Skipping 007-6162-300.jpg as mask is empty.
# Skipping 007-2278-100.jpg as mask is empty.
# Skipping 007-2300-100.jpg as mask is empty.
# Skipping 007-5944-300.jpg as mask is empty.
# Skipping 007-5688-300.jpg as mask is empty.
# Skipping 20170518104749319.jpg as mask is empty.
# Skipping 007-2402-100.jpg as mask is empty.
# Skipping 20170629163635747.jpg as mask is empty.
# Skipping 007-6713-400.jpg as mask is empty.
# Skipping 007-1975-100.jpg as mask is empty.
# Skipping 20170504094058352.jpg as mask is empty.
# Skipping 007-5803-300.jpg as mask is empty.
# Skipping 007-2470-100.jpg as mask is empty.
# Skipping 007-1921-100.jpg as mask is empty.
# Skipping 007-4660-200.jpg as mask is empty.
# Skipping 007-4035-200.jpg as mask is empty.
# Skipping 007-2295-100.jpg as mask is empty.
# Skipping 007-6240-300.jpg as mask is empty.
# Skipping 007-2677-100.jpg as mask is empty.
# Skipping 007-2479-100.jpg as mask is empty.
# Skipping 007-2469-100.jpg as mask is empty.
# Skipping 007-2326-100.jpg as mask is empty.
# Skipping 007-2808-100.jpg as mask is empty.
# Skipping 007-2181-100.jpg as mask is empty.
# Skipping 007-5346-300.jpg as mask is empty.
# Skipping 007-3417-200.jpg as mask is empty.

# %%
len(all_images), len(all_masks)
# Out:
# (483, 483)

# %%
# Split into training and test sets (80% train, 20% test)
train_images, test_images, train_masks, test_masks = train_test_split(
    all_images, all_masks, test_size=0.2, random_state=42
)

# split train set into training and validation sets (90% train, 10% validation)
train_images, val_images, train_masks, val_masks = train_test_split(
    train_images, train_masks, test_size=0.1, random_state=42
)

# %%
history = model.fit(train_images, train_masks, epochs=100,
                    batch_size=16, verbose=1, steps_per_epoch=len(train_images) // 16,
                    validation_data=(val_images, val_masks))
# Out:
# Epoch 1/100
# 2024-10-20 23:20:53.508048: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-10-20 23:20:54.022907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 21/21 [==============================] - ETA: 0s - loss: 1.1498 - accuracy: 0.9766 - iou_metric: 1.5394e-04 - dice_coefficient: 3.0688e-04
# 2024-10-20 23:21:18.320672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#
100
# 21/21 [==============================] - 24s 1s/step - loss: 0.8795 - accuracy: 0.9900 - iou_metric: 0.0973 - dice_coefficient: 0.1725 - val_loss: 0.9309 - val_accuracy: 0.9931 - val_iou_metric: 0.0688 - val_dice_coefficient: 0.1275
# Epoch 31/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.8033 - accuracy: 0.9959 - iou_metric: 0.1361 - dice_coefficient: 0.2366 - val_loss: 0.8299 - val_accuracy: 0.9968 - val_iou_metric: 0.1235 - val_dice_coefficient: 0.2166
# Epoch 32/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.7691 - accuracy: 0.9961 - iou_metric: 0.1570 - dice_coefficient: 0.2676 - val_loss: 0.8126 - val_accuracy: 0.9965 - val_iou_metric: 0.1267 - val_dice_coefficient: 0.2229
# Epoch 33/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.7686 - accuracy: 0.9952 - iou_metric: 0.1596 - dice_coefficient: 0.2720 - val_loss: 0.7809 - val_accuracy: 0.9970 - val_iou_metric: 0.1512 - val_dice_coefficient: 0.2602
# Epoch 34/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.7163 - accuracy: 0.9962 - iou_metric: 0.1905 - dice_coefficient: 0.3172 - val_loss: 0.7770 - val_accuracy: 0.9969 - val_iou_metric: 0.1617 - val_dice_coefficient: 0.2751
# Epoch 35/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.7154 - accuracy: 0.9962 - iou_metric: 0.1920 - dice_coefficient: 0.3195 - val_loss: 0.7390 - val_accuracy: 0.9975 - val_iou_metric: 0.1785 - val_dice_coefficient: 0.3007
# Epoch 36/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6830 - accuracy: 0.9964 - iou_metric: 0.2145 - dice_coefficient: 0.3516 - val_loss: 0.7361 - val_accuracy: 0.9981 - val_iou_metric: 0.1775 - val_dice_coefficient: 0.2996
# Epoch 37/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.6907 - accuracy: 0.9967 - iou_metric: 0.2122 - dice_coefficient: 0.3477 - val_loss: 0.7334 - val_accuracy: 0.9973 - val_iou_metric: 0.1856 - val_dice_coefficient: 0.3102
# Epoch 38/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6408 - accuracy: 0.9968 - iou_metric: 0.2466 - dice_coefficient: 0.3926 - val_loss: 0.7191 - val_accuracy: 0.9975 - val_iou_metric: 0.1919 - val_dice_coefficient: 0.3199
# Epoch 39/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.6851 - accuracy: 0.9963 - iou_metric: 0.2135 - dice_coefficient: 0.3487 - val_loss: 0.7022 - val_accuracy: 0.9976 - val_iou_metric: 0.2064 - val_dice_coefficient: 0.3398
# Epoch 40/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6492 - accuracy: 0.9964 - iou_metric: 0.2402 - dice_coefficient: 0.3833 - val_loss: 0.7211 - val_accuracy: 0.9983 - val_iou_metric: 0.1885 - val_dice_coefficient: 0.3151
# Epoch 41/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.6468 - accuracy: 0.9966 - iou_metric: 0.2415 - dice_coefficient: 0.3859 - val_loss: 0.6769 - val_accuracy: 0.9980 - val_iou_metric: 0.2207 - val_dice_coefficient: 0.3595
# Epoch 42/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6149 - accuracy: 0.9971 - iou_metric: 0.2652 - dice_coefficient: 0.4159 - val_loss: 0.6796 - val_accuracy: 0.9982 - val_iou_metric: 0.2196 - val_dice_coefficient: 0.3582
# Epoch 43/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6113 - accuracy: 0.9969 - iou_metric: 0.2704 - dice_coefficient: 0.4212 - val_loss: 0.6599 - val_accuracy: 0.9979 - val_iou_metric: 0.2360 - val_dice_coefficient: 0.3786
# Epoch 44/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6151 - accuracy: 0.9968 - iou_metric: 0.2669 - dice_coefficient: 0.4169 - val_loss: 0.6529 - val_accuracy: 0.9980 - val_iou_metric: 0.2401 - val_dice_coefficient: 0.3847
# Epoch 45/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6095 - accuracy: 0.9969 - iou_metric: 0.2702 - dice_coefficient: 0.4214 - val_loss: 0.6469 - val_accuracy: 0.9979 - val_iou_metric: 0.2472 - val_dice_coefficient: 0.3930
# Epoch 46/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.5897 - accuracy: 0.9969 - iou_metric: 0.2860 - dice_coefficient: 0.4389 - val_loss: 0.6460 - val_accuracy: 0.9982 - val_iou_metric: 0.2495 - val_dice_coefficient: 0.3962
# Epoch 47/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5740 - accuracy: 0.9973 - iou_metric: 0.2985 - dice_coefficient: 0.4555 - val_loss: 0.6464 - val_accuracy: 0.9982 - val_iou_metric: 0.2465 - val_dice_coefficient: 0.3926
# Epoch 48/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5612 - accuracy: 0.9970 - iou_metric: 0.3079 - dice_coefficient: 0.4667 - val_loss: 0.6301 - val_accuracy: 0.9984 - val_iou_metric: 0.2653 - val_dice_coefficient: 0.4147
# Epoch 49/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5715 - accuracy: 0.9969 - iou_metric: 0.2999 - dice_coefficient: 0.4574 - val_loss: 0.6120 - val_accuracy: 0.9984 - val_iou_metric: 0.2765 - val_dice_coefficient: 0.4296
# Epoch 50/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5467 - accuracy: 0.9975 - iou_metric: 0.3170 - dice_coefficient: 0.4788 - val_loss: 0.6106 - val_accuracy: 0.9984 - val_iou_metric: 0.2842 - val_dice_coefficient: 0.4368
# Epoch 51/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5710 - accuracy: 0.9967 - iou_metric: 0.3048 - dice_coefficient: 0.4624 - val_loss: 0.6357 - val_accuracy: 0.9986 - val_iou_metric: 0.2589 - val_dice_coefficient: 0.4073
# Epoch 52/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5628 - accuracy: 0.9975 - iou_metric: 0.3036 - dice_coefficient: 0.4607 - val_loss: 0.6188 - val_accuracy: 0.9978 - val_iou_metric: 0.2816 - val_dice_coefficient: 0.4329
# Epoch 53/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.6013 - accuracy: 0.9967 - iou_metric: 0.2755 - dice_coefficient: 0.4293 - val_loss: 0.6425 - val_accuracy: 0.9978 - val_iou_metric: 0.2604 - val_dice_coefficient: 0.4082
# Epoch 54/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5505 - accuracy: 0.9971 - iou_metric: 0.3183 - dice_coefficient: 0.4796 - val_loss: 0.6596 - val_accuracy: 0.9971 - val_iou_metric: 0.2421 - val_dice_coefficient: 0.3854
# Epoch 55/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5815 - accuracy: 0.9969 - iou_metric: 0.2936 - dice_coefficient: 0.4493 - val_loss: 0.6311 - val_accuracy: 0.9980 - val_iou_metric: 0.2567 - val_dice_coefficient: 0.4056
# Epoch 56/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5516 - accuracy: 0.9974 - iou_metric: 0.3172 - dice_coefficient: 0.4776 - val_loss: 0.6181 - val_accuracy: 0.9978 - val_iou_metric: 0.2763 - val_dice_coefficient: 0.4284
# Epoch 57/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5364 - accuracy: 0.9970 - iou_metric: 0.3294 - dice_coefficient: 0.4937 - val_loss: 0.6064 - val_accuracy: 0.9980 - val_iou_metric: 0.2894 - val_dice_coefficient: 0.4424
# Epoch 58/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5450 - accuracy: 0.9977 - iou_metric: 0.3208 - dice_coefficient: 0.4815 - val_loss: 0.5897 - val_accuracy: 0.9982 - val_iou_metric: 0.2995 - val_dice_coefficient: 0.4553
# Epoch 59/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5089 - accuracy: 0.9972 - iou_metric: 0.3547 - dice_coefficient: 0.5197 - val_loss: 0.5703 - val_accuracy: 0.9983 - val_iou_metric: 0.3120 - val_dice_coefficient: 0.4711
# Epoch 60/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5247 - accuracy: 0.9974 - iou_metric: 0.3420 - dice_coefficient: 0.5062 - val_loss: 0.5670 - val_accuracy: 0.9984 - val_iou_metric: 0.3154 - val_dice_coefficient: 0.4754
# Epoch 61/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5275 - accuracy: 0.9972 - iou_metric: 0.3350 - dice_coefficient: 0.4989 - val_loss: 0.5719 - val_accuracy: 0.9984 - val_iou_metric: 0.3074 - val_dice_coefficient: 0.4668
# Epoch 62/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5054 - accuracy: 0.9976 - iou_metric: 0.3576 - dice_coefficient: 0.5222 - val_loss: 0.5802 - val_accuracy: 0.9981 - val_iou_metric: 0.3044 - val_dice_coefficient: 0.4609
# Epoch 63/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4839 - accuracy: 0.9975 - iou_metric: 0.3768 - dice_coefficient: 0.5440 - val_loss: 0.5702 - val_accuracy: 0.9983 - val_iou_metric: 0.3102 - val_dice_coefficient: 0.4689
# Epoch 64/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5175 - accuracy: 0.9973 - iou_metric: 0.3462 - dice_coefficient: 0.5086 - val_loss: 0.5876 - val_accuracy: 0.9985 - val_iou_metric: 0.2888 - val_dice_coefficient: 0.4453
# Epoch 65/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5217 - accuracy: 0.9972 - iou_metric: 0.3414 - dice_coefficient: 0.5055 - val_loss: 0.5807 - val_accuracy: 0.9981 - val_iou_metric: 0.3038 - val_dice_coefficient: 0.4612
# Epoch 66/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5161 - accuracy: 0.9974 - iou_metric: 0.3486 - dice_coefficient: 0.5122 - val_loss: 0.5617 - val_accuracy: 0.9985 - val_iou_metric: 0.3218 - val_dice_coefficient: 0.4813
# Epoch 67/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5258 - accuracy: 0.9974 - iou_metric: 0.3405 - dice_coefficient: 0.5015 - val_loss: 0.5794 - val_accuracy: 0.9982 - val_iou_metric: 0.3092 - val_dice_coefficient: 0.4670
# Epoch 68/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5090 - accuracy: 0.9973 - iou_metric: 0.3547 - dice_coefficient: 0.5187 - val_loss: 0.5792 - val_accuracy: 0.9983 - val_iou_metric: 0.3103 - val_dice_coefficient: 0.4676
# Epoch 69/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5094 - accuracy: 0.9974 - iou_metric: 0.3521 - dice_coefficient: 0.5175 - val_loss: 0.6148 - val_accuracy: 0.9976 - val_iou_metric: 0.2779 - val_dice_coefficient: 0.4298
# Epoch 70/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5052 - accuracy: 0.9974 - iou_metric: 0.3572 - dice_coefficient: 0.5222 - val_loss: 0.5608 - val_accuracy: 0.9983 - val_iou_metric: 0.3223 - val_dice_coefficient: 0.4815
# Epoch 71/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4966 - accuracy: 0.9977 - iou_metric: 0.3619 - dice_coefficient: 0.5282 - val_loss: 0.5532 - val_accuracy: 0.9984 - val_iou_metric: 0.3262 - val_dice_coefficient: 0.4872
# Epoch 72/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4910 - accuracy: 0.9976 - iou_metric: 0.3669 - dice_coefficient: 0.5340 - val_loss: 0.5561 - val_accuracy: 0.9986 - val_iou_metric: 0.3219 - val_dice_coefficient: 0.4827
# Epoch 73/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4812 - accuracy: 0.9975 - iou_metric: 0.3768 - dice_coefficient: 0.5435 - val_loss: 0.5511 - val_accuracy: 0.9985 - val_iou_metric: 0.3301 - val_dice_coefficient: 0.4912
# Epoch 74/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4893 - accuracy: 0.9974 - iou_metric: 0.3727 - dice_coefficient: 0.5385 - val_loss: 0.5662 - val_accuracy: 0.9982 - val_iou_metric: 0.3162 - val_dice_coefficient: 0.4751
# Epoch 75/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.4936 - accuracy: 0.9976 - iou_metric: 0.3643 - dice_coefficient: 0.5308 - val_loss: 0.5329 - val_accuracy: 0.9985 - val_iou_metric: 0.3461 - val_dice_coefficient: 0.5099
# Epoch 76/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.4944 - accuracy: 0.9970 - iou_metric: 0.3677 - dice_coefficient: 0.5353 - val_loss: 0.5430 - val_accuracy: 0.9986 - val_iou_metric: 0.3314 - val_dice_coefficient: 0.4937
# Epoch 77/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4754 - accuracy: 0.9978 - iou_metric: 0.3819 - dice_coefficient: 0.5487 - val_loss: 0.5507 - val_accuracy: 0.9984 - val_iou_metric: 0.3203 - val_dice_coefficient: 0.4824
# Epoch 78/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4529 - accuracy: 0.9977 - iou_metric: 0.4031 - dice_coefficient: 0.5709 - val_loss: 0.5561 - val_accuracy: 0.9986 - val_iou_metric: 0.3205 - val_dice_coefficient: 0.4812
# Epoch 79/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4687 - accuracy: 0.9978 - iou_metric: 0.3866 - dice_coefficient: 0.5543 - val_loss: 0.5534 - val_accuracy: 0.9987 - val_iou_metric: 0.3293 - val_dice_coefficient: 0.4892
# Epoch 80/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4921 - accuracy: 0.9975 - iou_metric: 0.3695 - dice_coefficient: 0.5356 - val_loss: 0.5468 - val_accuracy: 0.9984 - val_iou_metric: 0.3277 - val_dice_coefficient: 0.4899
# Epoch 81/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4776 - accuracy: 0.9975 - iou_metric: 0.3799 - dice_coefficient: 0.5477 - val_loss: 0.5521 - val_accuracy: 0.9984 - val_iou_metric: 0.3264 - val_dice_coefficient: 0.4878
# Epoch 82/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.5109 - accuracy: 0.9972 - iou_metric: 0.3515 - dice_coefficient: 0.5166 - val_loss: 0.5394 - val_accuracy: 0.9985 - val_iou_metric: 0.3481 - val_dice_coefficient: 0.5082
# Epoch 83/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4551 - accuracy: 0.9977 - iou_metric: 0.4009 - dice_coefficient: 0.5678 - val_loss: 0.5253 - val_accuracy: 0.9985 - val_iou_metric: 0.3555 - val_dice_coefficient: 0.5193
# Epoch 84/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4751 - accuracy: 0.9973 - iou_metric: 0.3882 - dice_coefficient: 0.5547 - val_loss: 0.5253 - val_accuracy: 0.9985 - val_iou_metric: 0.3520 - val_dice_coefficient: 0.5168
# Epoch 85/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4677 - accuracy: 0.9979 - iou_metric: 0.3868 - dice_coefficient: 0.5551 - val_loss: 0.5375 - val_accuracy: 0.9986 - val_iou_metric: 0.3396 - val_dice_coefficient: 0.5018
# Epoch 86/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4598 - accuracy: 0.9976 - iou_metric: 0.3975 - dice_coefficient: 0.5645 - val_loss: 0.5259 - val_accuracy: 0.9987 - val_iou_metric: 0.3538 - val_dice_coefficient: 0.5170
# Epoch 87/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4757 - accuracy: 0.9974 - iou_metric: 0.3851 - dice_coefficient: 0.5510 - val_loss: 0.5285 - val_accuracy: 0.9984 - val_iou_metric: 0.3447 - val_dice_coefficient: 0.5093
# Epoch 88/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4546 - accuracy: 0.9977 - iou_metric: 0.4022 - dice_coefficient: 0.5693 - val_loss: 0.5302 - val_accuracy: 0.9984 - val_iou_metric: 0.3553 - val_dice_coefficient: 0.5171
# Epoch 89/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4493 - accuracy: 0.9976 - iou_metric: 0.4091 - dice_coefficient: 0.5757 - val_loss: 0.5290 - val_accuracy: 0.9984 - val_iou_metric: 0.3524 - val_dice_coefficient: 0.5153
# Epoch 90/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4487 - accuracy: 0.9975 - iou_metric: 0.4091 - dice_coefficient: 0.5766 - val_loss: 0.5105 - val_accuracy: 0.9987 - val_iou_metric: 0.3677 - val_dice_coefficient: 0.5332
# Epoch 91/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4266 - accuracy: 0.9980 - iou_metric: 0.4235 - dice_coefficient: 0.5926 - val_loss: 0.5105 - val_accuracy: 0.9987 - val_iou_metric: 0.3649 - val_dice_coefficient: 0.5306
# Epoch 92/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.4737 - accuracy: 0.9973 - iou_metric: 0.3888 - dice_coefficient: 0.5539 - val_loss: 0.5435 - val_accuracy: 0.9984 - val_iou_metric: 0.3390 - val_dice_coefficient: 0.5008
# Epoch 93/100
# 21/21 [==============================] - 26s 1s/step - loss: 0.4392 - accuracy: 0.9978 - iou_metric: 0.4168 - dice_coefficient: 0.5850 - val_loss: 0.5204 - val_accuracy: 0.9986 - val_iou_metric: 0.3571 - val_dice_coefficient: 0.5213
# Epoch 94/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.4571 - accuracy: 0.9978 - iou_metric: 0.3969 - dice_coefficient: 0.5650 - val_loss: 0.5353 - val_accuracy: 0.9986 - val_iou_metric: 0.3504 - val_dice_coefficient: 0.5121
# Epoch 95/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4606 - accuracy: 0.9978 - iou_metric: 0.3985 - dice_coefficient: 0.5646 - val_loss: 0.5216 - val_accuracy: 0.9984 - val_iou_metric: 0.3565 - val_dice_coefficient: 0.5213
# Epoch 96/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4730 - accuracy: 0.9972 - iou_metric: 0.3877 - dice_coefficient: 0.5536 - val_loss: 0.5438 - val_accuracy: 0.9982 - val_iou_metric: 0.3438 - val_dice_coefficient: 0.5046
# Epoch 97/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4212 - accuracy: 0.9979 - iou_metric: 0.4344 - dice_coefficient: 0.6011 - val_loss: 0.5155 - val_accuracy: 0.9986 - val_iou_metric: 0.3636 - val_dice_coefficient: 0.5281
# Epoch 98/100
# 21/21 [==============================] - 27s 1s/step - loss: 0.4771 - accuracy: 0.9978 - iou_metric: 0.3824 - dice_coefficient: 0.5476 - val_loss: 0.5397 - val_accuracy: 0.9985 - val_iou_metric: 0.3407 - val_dice_coefficient: 0.5025
# Epoch 99/100
# 21/21 [==============================] - 25s 1s/step - loss: 0.4613 - accuracy: 0.9975 - iou_metric: 0.3986 - dice_coefficient: 0.5645 - val_loss: 0.5025 - val_accuracy: 0.9985 - val_iou_metric: 0.3646 - val_dice_coefficient: 0.5320
# Epoch 100/100
# 21/21 [==============================] - 24s 1s/step - loss: 0.4228 - accuracy: 0.9979 - iou_metric: 0.4318 - dice_coefficient: 0.6000 - val_loss: 0.5207 - val_accuracy: 0.9984 - val_iou_metric: 0.3614 - val_dice_coefficient: 0.5246

# %%
scores = model.evaluate(val_images, val_masks)
print("Validation Loss: %.2f" % scores[0])
print("Validation Accuracy: %.2f%%" % (scores[1] * 100))
print("Validation IoU: %.2f%%" % (scores[2] * 100))
print("Validation Dice: %.2f%%" % (scores[3] * 100))
# Out:
# 2/2 [==============================] - 2s 345ms/step - loss: 0.5085 - accuracy: 0.9984 - iou_metric: 0.3952 - dice_coefficient: 0.5618
# Validation Loss: 0.51
# Validation Accuracy: 99.84%
# Validation IoU: 39.52%
# Validation Dice: 56.18%

# %%
scores = model.evaluate(test_images, test_masks)
print("Test Loss: %.2f" % scores[0])
print("Test Accuracy: %.2f%%" % (scores[1] * 100))
print("Test IoU: %.2f%%" % (scores[2] * 100))
print("Test Dice: %.2f%%" % (scores[3] * 100))
# Out:
# 4/4 [==============================] - 3s 734ms/step - loss: 0.4990 - accuracy: 0.9977 - iou_metric: 0.3718 - dice_coefficient: 0.5394
# Test Loss: 0.50
# Test Accuracy: 99.77%
# Test IoU: 37.18%
# Test Dice: 53.94%

# %% [markdown]
# ### Visualise

# %%
import matplotlib.pyplot as plt

image = all_images[151]  # Original test image
true_mask = all_masks[151]  # Ground truth mask

pred_mask_unet = model.predict(np.expand_dims(image, axis=0))  # Predict mask
pred_mask_unet_binary = (pred_mask_unet > 0.5).astype(int)  # Convert to binary

# pred_mask_resnet = model_resnet.predict(np.expand_dims(image, axis=0))  # Predict mask
# pred_mask_resnet_binary = (pred_mask_resnet > 0.5).astype(int)  # Convert to binary

# Function to visualize image, ground truth mask, and predicted mask
plt.figure(figsize=(8, 4))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(image)
plt.title("Original Image")
plt.axis('off')

# Ground truth mask
plt.subplot(2, 2, 2)
plt.imshow(true_mask.squeeze(), cmap='gray')
plt.title("Ground Truth Mask")
plt.axis('off')

# Predicted mask
plt.subplot(2, 2, 3)
plt.imshow(pred_mask_unet.squeeze(), cmap='gray')
plt.title("Predicted Mask UNet")
plt.axis('off')

# Predicted mask
plt.subplot(2, 2, 4)
plt.imshow(pred_mask_unet_binary.squeeze(), cmap='gray')
plt.title("Predicted Mask Threshold")
plt.axis('off')

plt.show()
# Out:
# 2024-10-21 00:05:33.855981: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 429ms/step

# %% [markdown]
# ### Save

# %%
# Save the model
model_json = model.to_json()
with open('../models_segmentation/EX.json', 'w') as json_file:
    json_file.write(model_json)

# Saving the model and weights
model.save_weights('../models_segmentation/EX.weights.h5')
