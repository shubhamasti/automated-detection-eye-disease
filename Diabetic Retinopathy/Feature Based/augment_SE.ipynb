# %%
import cv2
import os
import albumentations as A

# %%
# Define augmentation pipeline
augmentation_pipeline = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.5),
    A.GaussianBlur(var_limit=(10.0, 50.0), p=0.2),
    A.RandomGamma(gamma_limit=(80, 120), p=0.2),
    A.RandomResizedCrop(height=256, width=256, scale=(0.8, 1.0), p=0.3)
])

# Augment images and masks
def augment_image_and_mask(image, mask):
    augmented = augmentation_pipeline(image=image, mask=mask)
    return augmented['image'], augmented['mask']
# Out:
# /var/folders/fl/ngxwxtkd09l10m23llp7drg80000gn/T/ipykernel_71169/317270173.py:7: UserWarning: Argument 'alpha_affine' is not valid and will be ignored.
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.5),
# /var/folders/fl/ngxwxtkd09l10m23llp7drg80000gn/T/ipykernel_71169/317270173.py:8: UserWarning: Argument 'var_limit' is not valid and will be ignored.
#   A.GaussianBlur(var_limit=(10.0, 50.0), p=0.2),

# %%
# Load and augment images and masks
image_dir = "path/to/DDR/lesion_segmentation/all/image"
mask_dir = "path/to/DDR/lesion_segmentation/all/label/SE"

# %%
augmented_images = []
augmented_masks = []
negative_count = 0

for img_filename in os.listdir(image_dir):
    mask_filename = img_filename.replace('.jpg', '.tif')  # Adjust extensions as needed
    
    # Construct full paths for image and mask
    img_path = os.path.join(image_dir, img_filename)
    mask_path = os.path.join(mask_dir, mask_filename)
    
    # Check if both image and corresponding mask exist
    if os.path.exists(mask_path):
        # Load the image and mask
        image = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        if mask.max() <= 0:
            negative_count += 1
            if negative_count > 10:
                print(f"Reached 10 negative samples. Skipping file {img_filename}")
                continue
        
        # Augment the data
        for _ in range(3):  # Augment each image 3 times to reach the target size
            aug_image, aug_mask = augment_image_and_mask(image, mask)
            augmented_images.append(aug_image)
            augmented_masks.append(aug_mask)
# Out:
# Reached 10 negative samples. Skipping file 007-1774-100.jpg
# Reached 10 negative samples. Skipping file 007-6912-400.jpg
# Reached 10 negative samples. Skipping file 007-1811-100.jpg
# Reached 10 negative samples. Skipping file 007-3412-200.jpg
# Reached 10 negative samples. Skipping file 007-2160-100.jpg
# Reached 10 negative samples. Skipping file 007-3924-200.jpg
# Reached 10 negative samples. Skipping file 007-6683-400.jpg
# Reached 10 negative samples. Skipping file 007-3934-200.jpg
# Reached 10 negative samples. Skipping file 007-2453-100.jpg
# Reached 10 negative samples. Skipping file 007-3780-200.jpg
# Reached 10 negative samples. Skipping file 007-3729-200.jpg
# Reached 10 negative samples. Skipping file 007-4571-200.jpg
# Reached 10 negative samples. Skipping file 007-4561-200.jpg
# Reached 10 negative samples. Skipping file 007-3527-200.jpg
# Reached 10 negative samples. Skipping file 007-2840-100.jpg
# Reached 10 negative samples. Skipping file 20170616125321132.jpg
# Reached 10 negative samples. Skipping file 007-3372-200.jpg
# Reached 10 negative samples. Skipping file 007-2832-100.jpg
# Reached 10 negative samples. Skipping file 007-3310-200.jpg
# Reached 10 negative samples. Skipping file 20170511152728021.jpg
# Reached 10 negative samples. Skipping file 20170501232731664.jpg
# Reached 10 negative samples. Skipping file 007-4148-200.jpg
# Reached 10 negative samples. Skipping file 007-1946-100.jpg
# Reached 10 negative samples. Skipping file 007-4287-200.jpg
# Reached 10 negative samples. Skipping file 007-2112-100.jpg
# Reached 10 negative samples. Skipping file 007-3494-200.jpg
# Reached 10 negative samples. Skipping file 007-2757-100.jpg
# Reached 10 negative samples. Skipping file 20170511170800183.jpg
# Reached 10 negative samples. Skipping file 007-2771-100.jpg
# Reached 10 negative samples. Skipping file 007-2407-100.jpg
# Reached 10 negative samples. Skipping file 007-2252-100.jpg
# Reached 10 negative samples. Skipping file 007-3808-200.jpg
# Reached 10 negative samples. Skipping file 007-4006-200.jpg
# Reached 10 negative samples. Skipping file 20170511141336893.jpg
# Reached 10 negative samples. Skipping file 007-2383-100.jpg
# Reached 10 negative samples. Skipping file 007-3336-200.jpg
# Reached 10 negative samples. Skipping file 007-4557-200.jpg
# Reached 10 negative samples. Skipping file 007-6811-400.jpg
# Reached 10 negative samples. Skipping file 007-3319-200.jpg
# Reached 10 negative samples. Skipping file 007-3434-200.jpg
# Reached 10 negative samples. Skipping file 20170602084034474.jpg
# Reached 10 negative samples. Skipping file 007-3424-200.jpg
# Reached 10 negative samples. Skipping file 007-2481-100.jpg
# Reached 10 negative samples. Skipping file 20170518092011904.jpg
# Reached 10 negative samples. Skipping file 007-2428-100.jpg
# Reached 10 negative samples. Skipping file 007-3827-200.jpg
# Reached 10 negative samples. Skipping file 007-4090-200.jpg
# Reached 10 negative samples. Skipping file 007-3597-200.jpg
# Reached 10 negative samples. Skipping file 007-2998-100.jpg
# Reached 10 negative samples. Skipping file 007-5941-300.jpg
# Reached 10 negative samples. Skipping file 007-3789-200.jpg
# Reached 10 negative samples. Skipping file 007-3038-100.jpg
# Reached 10 negative samples. Skipping file 007-3984-200.jpg
# Reached 10 negative samples. Skipping file 007-3730-200.jpg
# Reached 10 negative samples. Skipping file 007-1789-100.jpg
# Reached 10 negative samples. Skipping file 007-2795-100.jpg
# Reached 10 negative samples. Skipping file 007-4568-200.jpg
# Reached 10 negative samples. Skipping file 007-4245-200.jpg
# Reached 10 negative samples. Skipping file 007-6545-400.jpg
# Reached 10 negative samples. Skipping file 007-1819-100.jpg
# Reached 10 negative samples. Skipping file 007-1971-100.jpg
# Reached 10 negative samples. Skipping file 007-4007-200.jpg
# Reached 10 negative samples. Skipping file 007-6717-400.jpg
# Reached 10 negative samples. Skipping file 007-6519-400.jpg
# Reached 10 negative samples. Skipping file 20170521094743135.jpg
# Reached 10 negative samples. Skipping file 007-2125-100.jpg
# Reached 10 negative samples. Skipping file 007-3971-200.jpg
# Reached 10 negative samples. Skipping file 007-2243-100.jpg
# Reached 10 negative samples. Skipping file 007-3500-200.jpg
# Reached 10 negative samples. Skipping file 007-3666-200.jpg
# Reached 10 negative samples. Skipping file 007-2288-100.jpg
# Reached 10 negative samples. Skipping file 007-2883-100.jpg
# Reached 10 negative samples. Skipping file 007-3425-200.jpg
# Reached 10 negative samples. Skipping file 007-6363-400.jpg
# Reached 10 negative samples. Skipping file 007-3308-200.jpg
# Reached 10 negative samples. Skipping file 20170522100404106.jpg
# Reached 10 negative samples. Skipping file 007-4038-200.jpg
# Reached 10 negative samples. Skipping file 007-3743-200.jpg
# Reached 10 negative samples. Skipping file 007-2848-100.jpg
# Reached 10 negative samples. Skipping file 007-4254-200.jpg
# Reached 10 negative samples. Skipping file 007-4244-200.jpg
# Reached 10 negative samples. Skipping file 20170515092404420.jpg
# Reached 10 negative samples. Skipping file 007-3457-200.jpg
# Reached 10 negative samples. Skipping file 007-5492-300.jpg
# Reached 10 negative samples. Skipping file 007-3854-200.jpg
# Reached 10 negative samples. Skipping file 007-2366-100.jpg
# Reached 10 negative samples. Skipping file 007-4680-200.jpg
# Reached 10 negative samples. Skipping file 007-2505-100.jpg
# Reached 10 negative samples. Skipping file 007-2228-100.jpg
# Reached 10 negative samples. Skipping file 007-6562-400.jpg
# Reached 10 negative samples. Skipping file 007-4262-200.jpg
# Reached 10 negative samples. Skipping file 007-3461-200.jpg
# Reached 10 negative samples. Skipping file 007-3509-200.jpg
# Reached 10 negative samples. Skipping file 007-4741-200.jpg
# Reached 10 negative samples. Skipping file 007-3765-200.jpg
# Reached 10 negative samples. Skipping file 007-4733-200.jpg
# Reached 10 negative samples. Skipping file 007-3413-200.jpg
# Reached 10 negative samples. Skipping file 007-2769-100.jpg
# Reached 10 negative samples. Skipping file 007-3397-200.jpg
# Reached 10 negative samples. Skipping file 007-3387-200.jpg
# Reached 10 negative samples. Skipping file 007-2567-100.jpg
# Reached 10 negative samples. Skipping file 007-2841-100.jpg
# Reached 10 negative samples. Skipping file 007-4560-200.jpg
# Reached 10 negative samples. Skipping file 007-3781-200.jpg
# Reached 10 negative samples. Skipping file 007-3485-200.jpg
# Reached 10 negative samples. Skipping file 007-2756-100.jpg
# Reached 10 negative samples. Skipping file 007-2697-100.jpg
# Reached 10 negative samples. Skipping file 007-3554-200.jpg
# Reached 10 negative samples. Skipping file 007-4347-200.jpg
# Reached 10 negative samples. Skipping file 007-7025-400.jpg
# Reached 10 negative samples. Skipping file 007-6721-400.jpg
# Reached 10 negative samples. Skipping file 007-6649-400.jpg
# Reached 10 negative samples. Skipping file 007-4159-200.jpg
# Reached 10 negative samples. Skipping file 20170521093504075.jpg
# Reached 10 negative samples. Skipping file 007-4674-200.jpg
# Reached 10 negative samples. Skipping file 007-2700-100.jpg
# Reached 10 negative samples. Skipping file 007-2155-100.jpg
# Reached 10 negative samples. Skipping file 007-4622-200.jpg
# Reached 10 negative samples. Skipping file 007-4269-200.jpg
# Reached 10 negative samples. Skipping file 007-3418-200.jpg
# Reached 10 negative samples. Skipping file 20170508222739885.jpg
# Reached 10 negative samples. Skipping file 007-4015-200.jpg
# Reached 10 negative samples. Skipping file 007-2390-100.jpg
# Reached 10 negative samples. Skipping file 007-2404-100.jpg
# Reached 10 negative samples. Skipping file 007-6908-400.jpg
# Reached 10 negative samples. Skipping file 007-2339-100.jpg
# Reached 10 negative samples. Skipping file 007-5086-300.jpg
# Reached 10 negative samples. Skipping file 007-3973-200.jpg
# Reached 10 negative samples. Skipping file 007-2127-100.jpg
# Reached 10 negative samples. Skipping file 007-3445-200.jpg
# Reached 10 negative samples. Skipping file 007-4246-200.jpg
# Reached 10 negative samples. Skipping file 007-3987-200.jpg
# Reached 10 negative samples. Skipping file 007-2449-100.jpg
# Reached 10 negative samples. Skipping file 20170512231011621.jpg
# Reached 10 negative samples. Skipping file 20170614102011786.jpg
# Reached 10 negative samples. Skipping file 007-3824-200.jpg
# Reached 10 negative samples. Skipping file 20170517171357632.jpg
# Reached 10 negative samples. Skipping file 007-3629-200.jpg
# Reached 10 negative samples. Skipping file 007-2492-100.jpg
# Reached 10 negative samples. Skipping file 007-1824-100.jpg
# Reached 10 negative samples. Skipping file 007-7146-400.jpg
# Reached 10 negative samples. Skipping file 007-4224-200.jpg
# Reached 10 negative samples. Skipping file 007-6361-400.jpg
# Reached 10 negative samples. Skipping file 007-3427-200.jpg
# Reached 10 negative samples. Skipping file 20170615145539585.jpg
# Reached 10 negative samples. Skipping file 007-7018-400.jpg
# Reached 10 negative samples. Skipping file 007-2976-100.jpg
# Reached 10 negative samples. Skipping file 007-3411-200.jpg
# Reached 10 negative samples. Skipping file 007-6674-400.jpg
# Reached 10 negative samples. Skipping file 007-2330-100.jpg
# Reached 10 negative samples. Skipping file 007-3812-200.jpg
# Reached 10 negative samples. Skipping file 007-4586-200.jpg
# Reached 10 negative samples. Skipping file 007-4743-200.jpg
# Reached 10 negative samples. Skipping file 007-6325-400.jpg
# Reached 10 negative samples. Skipping file 007-6335-400.jpg
# Reached 10 negative samples. Skipping file 007-3463-200.jpg
# Reached 10 negative samples. Skipping file 007-4318-200.jpg
# Reached 10 negative samples. Skipping file 007-4270-200.jpg
# Reached 10 negative samples. Skipping file 007-2079-100.jpg
# Reached 10 negative samples. Skipping file 007-3487-200.jpg
# Reached 10 negative samples. Skipping file 007-3040-100.jpg
# Reached 10 negative samples. Skipping file 007-1894-100.jpg
# Reached 10 negative samples. Skipping file 20170518171333730.jpg
# Reached 10 negative samples. Skipping file 007-4676-200.jpg
# Reached 10 negative samples. Skipping file 007-3748-200.jpg
# Reached 10 negative samples. Skipping file 007-4033-200.jpg
# Reached 10 negative samples. Skipping file 007-5452-300.jpg
# Reached 10 negative samples. Skipping file 20170504152732434.jpg
# Reached 10 negative samples. Skipping file 007-3361-200.jpg
# Reached 10 negative samples. Skipping file 007-4614-200.jpg
# Reached 10 negative samples. Skipping file 007-2450-100.jpg
# Reached 10 negative samples. Skipping file 007-2574-100.jpg
# Reached 10 negative samples. Skipping file 20170503161702278.jpg
# Reached 10 negative samples. Skipping file 007-2057-100.jpg
# Reached 10 negative samples. Skipping file 007-3400-200.jpg
# Reached 10 negative samples. Skipping file 007-4203-200.jpg
# Reached 10 negative samples. Skipping file 007-3766-200.jpg
# Reached 10 negative samples. Skipping file 20170519180821875.jpg
# Reached 10 negative samples. Skipping file 20170609154552424.jpg
# Reached 10 negative samples. Skipping file 007-4107-200.jpg
# Reached 10 negative samples. Skipping file 007-7265-400.jpg
# Reached 10 negative samples. Skipping file 007-1909-100.jpg
# Reached 10 negative samples. Skipping file 007-3462-200.jpg
# Reached 10 negative samples. Skipping file 007-2343-100.jpg
# Reached 10 negative samples. Skipping file 007-3895-200.jpg
# Reached 10 negative samples. Skipping file 007-4032-200.jpg
# Reached 10 negative samples. Skipping file 007-3759-200.jpg
# Reached 10 negative samples. Skipping file 007-4667-200.jpg
# Reached 10 negative samples. Skipping file 007-3749-200.jpg
# Reached 10 negative samples. Skipping file 007-4479-200.jpg
# Reached 10 negative samples. Skipping file 007-2684-100.jpg
# Reached 10 negative samples. Skipping file 007-2110-100.jpg
# Reached 10 negative samples. Skipping file 007-2068-100.jpg
# Reached 10 negative samples. Skipping file 007-4285-200.jpg
# Reached 10 negative samples. Skipping file 20170509162056178.jpg
# Reached 10 negative samples. Skipping file 007-6847-400.jpg
# Reached 10 negative samples. Skipping file 007-3792-200.jpg
# Reached 10 negative samples. Skipping file 007-2983-100.jpg
# Reached 10 negative samples. Skipping file 007-3370-200.jpg
# Reached 10 negative samples. Skipping file 007-2842-100.jpg
# Reached 10 negative samples. Skipping file 20170509100155767.jpg
# Reached 10 negative samples. Skipping file 007-2580-100.jpg
# Reached 10 negative samples. Skipping file 007-4605-200.jpg
# Reached 10 negative samples. Skipping file 007-1782-100.jpg
# Reached 10 negative samples. Skipping file 20170517163822454.jpg
# Reached 10 negative samples. Skipping file 007-1900-100.jpg
# Reached 10 negative samples. Skipping file 007-4066-200.jpg
# Reached 10 negative samples. Skipping file 007-4268-200.jpg
# Reached 10 negative samples. Skipping file 007-4310-200.jpg
# Reached 10 negative samples. Skipping file 007-6568-400.jpg
# Reached 10 negative samples. Skipping file 007-3503-200.jpg
# Reached 10 negative samples. Skipping file 007-2467-100.jpg
# Reached 10 negative samples. Skipping file 20170519153500194.jpg
# Reached 10 negative samples. Skipping file 007-2477-100.jpg
# Reached 10 negative samples. Skipping file 007-2232-100.jpg
# Reached 10 negative samples. Skipping file 20170525111826224.jpg
# Reached 10 negative samples. Skipping file 007-5087-300.jpg
# Reached 10 negative samples. Skipping file 20170518142454730.jpg
# Reached 10 negative samples. Skipping file 20170522165643535.jpg
# Reached 10 negative samples. Skipping file 007-3077-100.jpg
# Reached 10 negative samples. Skipping file 007-2415-100.jpg
# Reached 10 negative samples. Skipping file 007-2763-100.jpg
# Reached 10 negative samples. Skipping file 007-2773-100.jpg
# Reached 10 negative samples. Skipping file 007-2126-100.jpg
# Reached 10 negative samples. Skipping file 007-3571-200.jpg
# Reached 10 negative samples. Skipping file 007-2391-100.jpg
# Reached 10 negative samples. Skipping file 20170502000228274.jpg
# Reached 10 negative samples. Skipping file 20170516105337859.jpg
# Reached 10 negative samples. Skipping file 007-2375-100.jpg
# Reached 10 negative samples. Skipping file 007-2365-100.jpg
# Reached 10 negative samples. Skipping file 20170504101207303.jpg
# Reached 10 negative samples. Skipping file 20170605153241003.jpg
# Reached 10 negative samples. Skipping file 007-6547-400.jpg
# Reached 10 negative samples. Skipping file 007-7125-400.jpg
# Reached 10 negative samples. Skipping file 007-4402-200.jpg
# Reached 10 negative samples. Skipping file 007-2787-100.jpg
# Reached 10 negative samples. Skipping file 007-3444-200.jpg
# Reached 10 negative samples. Skipping file 007-3454-200.jpg
# Reached 10 negative samples. Skipping file 007-3722-200.jpg
# Reached 10 negative samples. Skipping file 007-7253-400.jpg
# Reached 10 negative samples. Skipping file 007-3986-200.jpg
# Reached 10 negative samples. Skipping file 007-4059-200.jpg
# Reached 10 negative samples. Skipping file 007-3638-200.jpg
# Reached 10 negative samples. Skipping file 007-3750-200.jpg
# Reached 10 negative samples. Skipping file 007-3628-200.jpg
# Reached 10 negative samples. Skipping file 007-4518-200.jpg
# Reached 10 negative samples. Skipping file 007-4470-200.jpg
# Reached 10 negative samples. Skipping file 007-6525-400.jpg
# Reached 10 negative samples. Skipping file 007-4225-200.jpg
# Reached 10 negative samples. Skipping file 20170515172948707.jpg
# Reached 10 negative samples. Skipping file 007-2525-100.jpg
# Reached 10 negative samples. Skipping file 007-2218-100.jpg
# Reached 10 negative samples. Skipping file 007-3737-200.jpg
# Reached 10 negative samples. Skipping file 007-4761-200.jpg
# Reached 10 negative samples. Skipping file 007-3727-200.jpg
# Reached 10 negative samples. Skipping file 007-3983-200.jpg
# Reached 10 negative samples. Skipping file 007-4252-200.jpg
# Reached 10 negative samples. Skipping file 20170504152807089.jpg
# Reached 10 negative samples. Skipping file 007-3539-200.jpg
# Reached 10 negative samples. Skipping file 007-4465-200.jpg
# Reached 10 negative samples. Skipping file 007-4220-200.jpg
# Reached 10 negative samples. Skipping file 007-4230-200.jpg
# Reached 10 negative samples. Skipping file 007-3745-200.jpg
# Reached 10 negative samples. Skipping file 007-2486-100.jpg
# Reached 10 negative samples. Skipping file 007-3820-200.jpg
# Reached 10 negative samples. Skipping file 007-1889-100.jpg
# Reached 10 negative samples. Skipping file 007-2631-100.jpg
# Reached 10 negative samples. Skipping file 007-2621-100.jpg
# Reached 10 negative samples. Skipping file 007-4540-200.jpg
# Reached 10 negative samples. Skipping file 20170502092651558.jpg
# Reached 10 negative samples. Skipping file 20170505161143089.jpg
# Reached 10 negative samples. Skipping file 20170503161702100.jpg
# Reached 10 negative samples. Skipping file 007-2151-100.jpg
# Reached 10 negative samples. Skipping file 007-2704-100.jpg
# Reached 10 negative samples. Skipping file 007-3398-200.jpg
# Reached 10 negative samples. Skipping file 20170503161012969.jpg
# Reached 10 negative samples. Skipping file 007-2245-100.jpg
# Reached 10 negative samples. Skipping file 007-1977-100.jpg
# Reached 10 negative samples. Skipping file 007-4169-200.jpg
# Reached 10 negative samples. Skipping file 007-2394-100.jpg
# Reached 10 negative samples. Skipping file 20170504113211634.jpg
# Reached 10 negative samples. Skipping file 20170504113211152.jpg
# Reached 10 negative samples. Skipping file 007-3552-200.jpg
# Reached 10 negative samples. Skipping file 007-7023-400.jpg
# Reached 10 negative samples. Skipping file 007-4341-200.jpg
# Reached 10 negative samples. Skipping file 007-1829-100.jpg
# Reached 10 negative samples. Skipping file 007-4662-200.jpg
# Reached 10 negative samples. Skipping file 20170501235455424.jpg
# Reached 10 negative samples. Skipping file 007-6590-400.jpg
# Reached 10 negative samples. Skipping file 007-4290-200.jpg
# Reached 10 negative samples. Skipping file 007-2167-100.jpg
# Reached 10 negative samples. Skipping file 007-3797-200.jpg
# Reached 10 negative samples. Skipping file 007-2454-100.jpg
# Reached 10 negative samples. Skipping file 007-3787-200.jpg
# Reached 10 negative samples. Skipping file 007-3036-100.jpg
# Reached 10 negative samples. Skipping file 007-3933-200.jpg
# Reached 10 negative samples. Skipping file 007-2369-100.jpg
# Reached 10 negative samples. Skipping file 007-4610-200.jpg
# Reached 10 negative samples. Skipping file 20170525181244148.jpg
# Reached 10 negative samples. Skipping file 007-4576-200.jpg
# Reached 10 negative samples. Skipping file 007-3458-200.jpg
# Reached 10 negative samples. Skipping file 007-4566-200.jpg
# Reached 10 negative samples. Skipping file 007-2607-100.jpg
# Reached 10 negative samples. Skipping file 007-4160-200.jpg
# Reached 10 negative samples. Skipping file 007-4170-200.jpg
# Reached 10 negative samples. Skipping file 007-3415-200.jpg
# Reached 10 negative samples. Skipping file 007-5501-300.jpg
# Reached 10 negative samples. Skipping file 007-3338-200.jpg
# Reached 10 negative samples. Skipping file 007-4264-200.jpg
# Reached 10 negative samples. Skipping file 007-4559-200.jpg
# Reached 10 negative samples. Skipping file 007-3711-200.jpg
# Reached 10 negative samples. Skipping file 007-3669-200.jpg
# Reached 10 negative samples. Skipping file 007-4747-200.jpg
# Reached 10 negative samples. Skipping file 007-2287-100.jpg
# Reached 10 negative samples. Skipping file 007-6612-400.jpg
# Reached 10 negative samples. Skipping file 007-2297-100.jpg
# Reached 10 negative samples. Skipping file 007-2503-100.jpg
# Reached 10 negative samples. Skipping file 007-3874-200.jpg
# Reached 10 negative samples. Skipping file 20170502092649506.jpg
# Reached 10 negative samples. Skipping file 007-3045-100.jpg
# Reached 10 negative samples. Skipping file 007-2272-100.jpg
# Reached 10 negative samples. Skipping file 007-6591-400.jpg
# Reached 10 negative samples. Skipping file 007-3492-200.jpg
# Reached 10 negative samples. Skipping file 007-4238-200.jpg
# Reached 10 negative samples. Skipping file 007-3553-200.jpg
# Reached 10 negative samples. Skipping file 20170508100750271.jpg
# Reached 10 negative samples. Skipping file 007-2594-100.jpg
# Reached 10 negative samples. Skipping file 007-4769-200.jpg
# Reached 10 negative samples. Skipping file 007-4567-200.jpg
# Reached 10 negative samples. Skipping file 007-3459-200.jpg
# Reached 10 negative samples. Skipping file 007-2846-100.jpg
# Reached 10 negative samples. Skipping file 007-2210-100.jpg
# Reached 10 negative samples. Skipping file 007-2378-100.jpg
# Reached 10 negative samples. Skipping file 007-2200-100.jpg
# Reached 10 negative samples. Skipping file 007-4171-200.jpg
# Reached 10 negative samples. Skipping file 007-7175-400.jpg
# Reached 10 negative samples. Skipping file 007-4217-200.jpg
# Reached 10 negative samples. Skipping file 007-3339-200.jpg
# Reached 10 negative samples. Skipping file 007-4207-200.jpg
# Reached 10 negative samples. Skipping file 007-3414-200.jpg
# Reached 10 negative samples. Skipping file 007-3380-200.jpg
# Reached 10 negative samples. Skipping file 007-2408-100.jpg
# Reached 10 negative samples. Skipping file 007-2335-100.jpg
# Reached 10 negative samples. Skipping file 20170509155323919.jpg
# Reached 10 negative samples. Skipping file 007-3008-100.jpg
# Reached 10 negative samples. Skipping file 007-4687-200.jpg
# Reached 10 negative samples. Skipping file 20170518144500812.jpg
# Reached 10 negative samples. Skipping file 007-4558-200.jpg
# Reached 10 negative samples. Skipping file 007-3466-200.jpg
# Reached 10 negative samples. Skipping file 007-4548-200.jpg
# Reached 10 negative samples. Skipping file 007-6320-400.jpg
# Reached 10 negative samples. Skipping file 007-3476-200.jpg
# Reached 10 negative samples. Skipping file 20170505181200498.jpg
# Reached 10 negative samples. Skipping file 007-1853-100.jpg
# Reached 10 negative samples. Skipping file 007-3538-200.jpg
# Reached 10 negative samples. Skipping file 007-3440-200.jpg
# Reached 10 negative samples. Skipping file 20170502161755715.jpg
# Reached 10 negative samples. Skipping file 007-3528-200.jpg
# Corrupt JPEG data: 36 extraneous bytes before marker 0xd9
# Reached 10 negative samples. Skipping file 007-2371-100.jpg
# Reached 10 negative samples. Skipping file 20170502095044024.jpg
# Reached 10 negative samples. Skipping file 007-2689-100.jpg
# Reached 10 negative samples. Skipping file 007-3744-200.jpg
# Reached 10 negative samples. Skipping file 20170516092409004.jpg
# Reached 10 negative samples. Skipping file 007-1831-100.jpg
# Reached 10 negative samples. Skipping file 007-2705-100.jpg
# Reached 10 negative samples. Skipping file 20170524102406516.jpg
# Reached 10 negative samples. Skipping file 007-4541-200.jpg
# Reached 10 negative samples. Skipping file 007-3517-200.jpg
# Reached 10 negative samples. Skipping file 20170508093934243.jpg
# Reached 10 negative samples. Skipping file 20170512123426558.jpg
# Reached 10 negative samples. Skipping file 007-3671-200.jpg
# Reached 10 negative samples. Skipping file 007-4655-200.jpg
# Reached 10 negative samples. Skipping file 007-2395-100.jpg
# Reached 10 negative samples. Skipping file 007-4168-200.jpg
# Reached 10 negative samples. Skipping file 007-4178-200.jpg
# Reached 10 negative samples. Skipping file 007-7014-400.jpg
# Reached 10 negative samples. Skipping file 20170504152654027.jpg
# Reached 10 negative samples. Skipping file 007-3399-200.jpg
# Reached 10 negative samples. Skipping file 20170511224838938.jpg
# Reached 10 negative samples. Skipping file 007-2401-100.jpg
# Reached 10 negative samples. Skipping file 007-3966-200.jpg
# Reached 10 negative samples. Skipping file 007-4258-200.jpg
# Reached 10 negative samples. Skipping file 007-2788-100.jpg
# Reached 10 negative samples. Skipping file 007-4613-200.jpg
# Reached 10 negative samples. Skipping file 007-3645-200.jpg
# Reached 10 negative samples. Skipping file 20170517153024404.jpg
# Reached 10 negative samples. Skipping file 007-2457-100.jpg
# Reached 10 negative samples. Skipping file 007-3784-200.jpg
# Reached 10 negative samples. Skipping file 007-2753-100.jpg
# Reached 10 negative samples. Skipping file 007-4283-200.jpg
# Reached 10 negative samples. Skipping file 20170511083029837.jpg
# Reached 10 negative samples. Skipping file 007-5856-300.jpg
# Reached 10 negative samples. Skipping file 007-6734-400.jpg
# Reached 10 negative samples. Skipping file 007-3883-200.jpg
# Reached 10 negative samples. Skipping file 007-4034-200.jpg
# Reached 10 negative samples. Skipping file 007-3627-200.jpg
# Reached 10 negative samples. Skipping file 007-4661-200.jpg
# Reached 10 negative samples. Skipping file 007-3551-200.jpg
# Reached 10 negative samples. Skipping file 007-4517-200.jpg
# Reached 10 negative samples. Skipping file 007-2682-100.jpg
# Reached 10 negative samples. Skipping file 007-3541-200.jpg
# Reached 10 negative samples. Skipping file 20170615104926501.jpg
# Reached 10 negative samples. Skipping file 007-2836-100.jpg
# Reached 10 negative samples. Skipping file 007-2468-100.jpg
# Reached 10 negative samples. Skipping file 007-2345-100.jpg
# Reached 10 negative samples. Skipping file 20170502204843387.jpg
# Reached 10 negative samples. Skipping file 007-4277-200.jpg
# Reached 10 negative samples. Skipping file 007-3416-200.jpg
# Reached 10 negative samples. Skipping file 007-5347-300.jpg
# Reached 10 negative samples. Skipping file 007-6505-400.jpg
# Reached 10 negative samples. Skipping file 007-2809-100.jpg
# Reached 10 negative samples. Skipping file 007-4163-200.jpg
# Reached 10 negative samples. Skipping file 007-4173-200.jpg
# Reached 10 negative samples. Skipping file 007-4840-300.jpg
# Reached 10 negative samples. Skipping file 007-5286-300.jpg
# Reached 10 negative samples. Skipping file 007-3489-200.jpg
# Reached 10 negative samples. Skipping file 007-3499-200.jpg
# Reached 10 negative samples. Skipping file 007-2067-100.jpg
# Reached 10 negative samples. Skipping file 007-2279-100.jpg
# Reached 10 negative samples. Skipping file 007-4145-200.jpg
# Reached 10 negative samples. Skipping file 007-3756-200.jpg
# Reached 10 negative samples. Skipping file 20170502085516832.jpg
# Reached 10 negative samples. Skipping file 007-3430-200.jpg
# Reached 10 negative samples. Skipping file 007-3420-200.jpg
# Reached 10 negative samples. Skipping file 007-6551-400.jpg
# Reached 10 negative samples. Skipping file 007-3452-200.jpg
# Reached 10 negative samples. Skipping file 007-3980-200.jpg
# Reached 10 negative samples. Skipping file 20170617103821616.jpg
# Reached 10 negative samples. Skipping file 007-6637-400.jpg
# Reached 10 negative samples. Skipping file 20170523093010553.jpg
# Reached 10 negative samples. Skipping file 007-3939-200.jpg
# Reached 10 negative samples. Skipping file 007-3929-200.jpg
# Reached 10 negative samples. Skipping file 20170508101423579.jpg
# Reached 10 negative samples. Skipping file 007-3567-200.jpg
# Reached 10 negative samples. Skipping file 007-1974-100.jpg
# Reached 10 negative samples. Skipping file 007-2397-100.jpg
# Reached 10 negative samples. Skipping file 007-4657-200.jpg
# Reached 10 negative samples. Skipping file 007-3779-200.jpg
# Reached 10 negative samples. Skipping file 20170521094903529.jpg
# Reached 10 negative samples. Skipping file 20170521095717085.jpg
# Reached 10 negative samples. Skipping file 007-2403-100.jpg
# Reached 10 negative samples. Skipping file 007-2765-100.jpg
# Reached 10 negative samples. Skipping file 007-6392-400.jpg
# Reached 10 negative samples. Skipping file 007-4482-200.jpg
# Reached 10 negative samples. Skipping file 007-2471-100.jpg
# Reached 10 negative samples. Skipping file 007-6815-400.jpg
# Reached 10 negative samples. Skipping file 007-3916-200.jpg
# Corrupt JPEG data: 40 extraneous bytes before marker 0xd9
# Reached 10 negative samples. Skipping file 007-2234-100.jpg
# Reached 10 negative samples. Skipping file 007-3673-200.jpg
# Reached 10 negative samples. Skipping file 007-6608-400.jpg
# Reached 10 negative samples. Skipping file 007-4070-200.jpg
# Reached 10 negative samples. Skipping file 007-4679-200.jpg
# Reached 10 negative samples. Skipping file 007-7236-400.jpg
# Reached 10 negative samples. Skipping file 20170514222515286.jpg
# Reached 10 negative samples. Skipping file 007-4467-200.jpg
# Reached 10 negative samples. Skipping file 007-3559-200.jpg
# Reached 10 negative samples. Skipping file 007-3431-200.jpg
# Reached 10 negative samples. Skipping file 007-2278-100.jpg
# Reached 10 negative samples. Skipping file 007-2300-100.jpg
# Reached 10 negative samples. Skipping file 007-3928-200.jpg
# Reached 10 negative samples. Skipping file 007-7132-400.jpg
# Reached 10 negative samples. Skipping file 20170502160448258.jpg
# Reached 10 negative samples. Skipping file 007-4240-200.jpg
# Reached 10 negative samples. Skipping file 20170510144008679.jpg
# Reached 10 negative samples. Skipping file 007-2402-100.jpg
# Reached 10 negative samples. Skipping file 20170629163635747.jpg
# Reached 10 negative samples. Skipping file 007-3975-200.jpg
# Reached 10 negative samples. Skipping file 007-2764-100.jpg
# Reached 10 negative samples. Skipping file 20170517153118932.jpg
# Reached 10 negative samples. Skipping file 007-4520-200.jpg
# Reached 10 negative samples. Skipping file 007-4013-200.jpg
# Reached 10 negative samples. Skipping file 007-6713-400.jpg
# Reached 10 negative samples. Skipping file 007-7219-400.jpg
# Reached 10 negative samples. Skipping file 007-1975-100.jpg
# Reached 10 negative samples. Skipping file 007-4071-200.jpg
# Reached 10 negative samples. Skipping file 007-4061-200.jpg
# Reached 10 negative samples. Skipping file 20170506085734414.jpg
# Reached 10 negative samples. Skipping file 20170504094058352.jpg
# Reached 10 negative samples. Skipping file 007-6383-400.jpg
# Reached 10 negative samples. Skipping file 20170502000225658.jpg
# Reached 10 negative samples. Skipping file 007-2460-100.jpg
# Reached 10 negative samples. Skipping file 007-2470-100.jpg
# Reached 10 negative samples. Skipping file 007-3921-200.jpg
# Reached 10 negative samples. Skipping file 007-3785-200.jpg
# Reached 10 negative samples. Skipping file 007-3377-200.jpg
# Reached 10 negative samples. Skipping file 007-1921-100.jpg
# Reached 10 negative samples. Skipping file 007-4660-200.jpg
# Reached 10 negative samples. Skipping file 007-3892-200.jpg
# Reached 10 negative samples. Skipping file 007-4035-200.jpg
# Reached 10 negative samples. Skipping file 007-4282-200.jpg
# Reached 10 negative samples. Skipping file 007-3491-200.jpg
# Reached 10 negative samples. Skipping file 007-2295-100.jpg
# Reached 10 negative samples. Skipping file 007-4433-200.jpg
# Reached 10 negative samples. Skipping file 007-4266-200.jpg
# Reached 10 negative samples. Skipping file 007-6576-400.jpg
# Reached 10 negative samples. Skipping file 007-2677-100.jpg
# Reached 10 negative samples. Skipping file 007-3876-200.jpg
# Reached 10 negative samples. Skipping file 007-2479-100.jpg
# Reached 10 negative samples. Skipping file 007-2469-100.jpg
# Reached 10 negative samples. Skipping file 007-6907-400.jpg
# Reached 10 negative samples. Skipping file 007-3814-200.jpg
# Reached 10 negative samples. Skipping file 007-2326-100.jpg
# Reached 10 negative samples. Skipping file 007-2808-100.jpg
# Reached 10 negative samples. Skipping file 007-7176-400.jpg
# Reached 10 negative samples. Skipping file 007-2181-100.jpg
# Reached 10 negative samples. Skipping file 007-4204-200.jpg
# Reached 10 negative samples. Skipping file 007-3417-200.jpg
# Reached 10 negative samples. Skipping file 007-3761-200.jpg

# %%
len(augmented_images), len(augmented_masks)
# Out:
# (747, 747)

# %%
augmented_image_dir = "path/to/augmented/dir/SEAugmented/Images"
augmented_mask_dir = "path/to/augmented/dir/SEAugmented/Masks"

# Ensure the directories exist
os.makedirs(augmented_image_dir, exist_ok=True)
os.makedirs(augmented_mask_dir, exist_ok=True)

# Save augmented images and masks
for idx, (aug_image, aug_mask) in enumerate(zip(augmented_images, augmented_masks)):
    img_path = os.path.join(augmented_image_dir, f'{idx}.jpg')
    mask_path = os.path.join(augmented_mask_dir, f'{idx}.tif')
    
    cv2.imwrite(img_path, aug_image)
    cv2.imwrite(mask_path, aug_mask)
    
    print(f'Saved augmented image and mask {idx}')
# Out:
# Saved augmented image and mask 0
# Saved augmented image and mask 1
# Saved augmented image and mask 2
# Saved augmented image and mask 3
# Saved augmented image and mask 4
# Saved augmented image and mask 5
# Saved augmented image and mask 6
# Saved augmented image and mask 7
# Saved augmented image and mask 8
# Saved augmented image and mask 9
# Saved augmented image and mask 10
# Saved augmented image and mask 11
# Saved augmented image and mask 12
# Saved augmented image and mask 13
# Saved augmented image and mask 14
# Saved augmented image and mask 15
# Saved augmented image and mask 16
# Saved augmented image and mask 17
# Saved augmented image and mask 18
# Saved augmented image and mask 19
# Saved augmented image and mask 20
# Saved augmented image and mask 21
# Saved augmented image and mask 22
# Saved augmented image and mask 23
# Saved augmented image and mask 24
# Saved augmented image and mask 25
# Saved augmented image and mask 26
# Saved augmented image and mask 27
# Saved augmented image and mask 28
# Saved augmented image and mask 29
# Saved augmented image and mask 30
# Saved augmented image and mask 31
# Saved augmented image and mask 32
# Saved augmented image and mask 33
# Saved augmented image and mask 34
# Saved augmented image and mask 35
# Saved augmented image and mask 36
# Saved augmented image and mask 37
# Saved augmented image and mask 38
# Saved augmented image and mask 39
# Saved augmented image and mask 40
# Saved augmented image and mask 41
# Saved augmented image and mask 42
# Saved augmented image and mask 43
# Saved augmented image and mask 44
# Saved augmented image and mask 45
# Saved augmented image and mask 46
# Saved augmented image and mask 47
# Saved augmented image and mask 48
# Saved augmented image and mask 49
# Saved augmented image and mask 50
# Saved augmented image and mask 51
# Saved augmented image and mask 52
# Saved augmented image and mask 53
# Saved augmented image and mask 54
# Saved augmented image and mask 55
# Saved augmented image and mask 56
# Saved augmented image and mask 57
# Saved augmented image and mask 58
# Saved augmented image and mask 59
# Saved augmented image and mask 60
# Saved augmented image and mask 61
# Saved augmented image and mask 62
# Saved augmented image and mask 63
# Saved augmented image and mask 64
# Saved augmented image and mask 65
# Saved augmented image and mask 66
# Saved augmented image and mask 67
# Saved augmented image and mask 68
# Saved augmented image and mask 69
# Saved augmented image and mask 70
# Saved augmented image and mask 71
# Saved augmented image and mask 72
# Saved augmented image and mask 73
# Saved augmented image and mask 74
# Saved augmented image and mask 75
# Saved augmented image and mask 76
# Saved augmented image and mask 77
# Saved augmented image and mask 78
# Saved augmented image and mask 79
# Saved augmented image and mask 80
# Saved augmented image and mask 81
# Saved augmented image and mask 82
# Saved augmented image and mask 83
# Saved augmented image and mask 84
# Saved augmented image and mask 85
# Saved augmented image and mask 86
# Saved augmented image and mask 87
# Saved augmented image and mask 88
# Saved augmented image and mask 89
# Saved augmented image and mask 90
# Saved augmented image and mask 91
# Saved augmented image and mask 92
# Saved augmented image and mask 93
# Saved augmented image and mask 94
# Saved augmented image and mask 95
# Saved augmented image and mask 96
# Saved augmented image and mask 97
# Saved augmented image and mask 98
# Saved augmented image and mask 99
# Saved augmented image and mask 100
# Saved augmented image and mask 101
# Saved augmented image and mask 102
# Saved augmented image and mask 103
# Saved augmented image and mask 104
# Saved augmented image and mask 105
# Saved augmented image and mask 106
# Saved augmented image and mask 107
# Saved augmented image and mask 108
# Saved augmented image and mask 109
# Saved augmented image and mask 110
# Saved augmented image and mask 111
# Saved augmented image and mask 112
# Saved augmented image and mask 113
# Saved augmented image and mask 114
# Saved augmented image and mask 115
# Saved augmented image and mask 116
# Saved augmented image and mask 117
# Saved augmented image and mask 118
# Saved augmented image and mask 119
# Saved augmented image and mask 120
# Saved augmented image and mask 121
# Saved augmented image and mask 122
# Saved augmented image and mask 123
# Saved augmented image and mask 124
# Saved augmented image and mask 125
# Saved augmented image and mask 126
# Saved augmented image and mask 127
# Saved augmented image and mask 128
# Saved augmented image and mask 129
# Saved augmented image and mask 130
# Saved augmented image and mask 131
# Saved augmented image and mask 132
# Saved augmented image and mask 133
# Saved augmented image and mask 134
# Saved augmented image and mask 135
# Saved augmented image and mask 136
# Saved augmented image and mask 137
# Saved augmented image and mask 138
# Saved augmented image and mask 139
# Saved augmented image and mask 140
# Saved augmented image and mask 141
# Saved augmented image and mask 142
# Saved augmented image and mask 143
# Saved augmented image and mask 144
# Saved augmented image and mask 145
# Saved augmented image and mask 146
# Saved augmented image and mask 147
# Saved augmented image and mask 148
# Saved augmented image and mask 149
# Saved augmented image and mask 150
# Saved augmented image and mask 151
# Saved augmented image and mask 152
# Saved augmented image and mask 153
# Saved augmented image and mask 154
# Saved augmented image and mask 155
# Saved augmented image and mask 156
# Saved augmented image and mask 157
# Saved augmented image and mask 158
# Saved augmented image and mask 159
# Saved augmented image and mask 160
# Saved augmented image and mask 161
# Saved augmented image and mask 162
# Saved augmented image and mask 163
# Saved augmented image and mask 164
# Saved augmented image and mask 165
# Saved augmented image and mask 166
# Saved augmented image and mask 167
# Saved augmented image and mask 168
# Saved augmented image and mask 169
# Saved augmented image and mask 170
# Saved augmented image and mask 171
# Saved augmented image and mask 172
# Saved augmented image and mask 173
# Saved augmented image and mask 174
# Saved augmented image and mask 175
# Saved augmented image and mask 176
# Saved augmented image and mask 177
# Saved augmented image and mask 178
# Saved augmented image and mask 179
# Saved augmented image and mask 180
# Saved augmented image and mask 181
# Saved augmented image and mask 182
# Saved augmented image and mask 183
# Saved augmented image and mask 184
# Saved augmented image and mask 185
# Saved augmented image and mask 186
# Saved augmented image and mask 187
# Saved augmented image and mask 188
# Saved augmented image and mask 189
# Saved augmented image and mask 190
# Saved augmented image and mask 191
# Saved augmented image and mask 192
# Saved augmented image and mask 193
# Saved augmented image and mask 194
# Saved augmented image and mask 195
# Saved augmented image and mask 196
# Saved augmented image and mask 197
# Saved augmented image and mask 198
# Saved augmented image and mask 199
# Saved augmented image and mask 200
# Saved augmented image and mask 201
# Saved augmented image and mask 202
# Saved augmented image and mask 203
# Saved augmented image and mask 204
# Saved augmented image and mask 205
# Saved augmented image and mask 206
# Saved augmented image and mask 207
# Saved augmented image and mask 208
# Saved augmented image and mask 209
# Saved augmented image and mask 210
# Saved augmented image and mask 211
# Saved augmented image and mask 212
# Saved augmented image and mask 213
# Saved augmented image and mask 214
# Saved augmented image and mask 215
# Saved augmented image and mask 216
# Saved augmented image and mask 217
# Saved augmented image and mask 218
# Saved augmented image and mask 219
# Saved augmented image and mask 220
# Saved augmented image and mask 221
# Saved augmented image and mask 222
# Saved augmented image and mask 223
# Saved augmented image and mask 224
# Saved augmented image and mask 225
# Saved augmented image and mask 226
# Saved augmented image and mask 227
# Saved augmented image and mask 228
# Saved augmented image and mask 229
# Saved augmented image and mask 230
# Saved augmented image and mask 231
# Saved augmented image and mask 232
# Saved augmented image and mask 233
# Saved augmented image and mask 234
# Saved augmented image and mask 235
# Saved augmented image and mask 236
# Saved augmented image and mask 237
# Saved augmented image and mask 238
# Saved augmented image and mask 239
# Saved augmented image and mask 240
# Saved augmented image and mask 241
# Saved augmented image and mask 242
# Saved augmented image and mask 243
# Saved augmented image and mask 244
# Saved augmented image and mask 245
# Saved augmented image and mask 246
# Saved augmented image and mask 247
# Saved augmented image and mask 248
# Saved augmented image and mask 249
# Saved augmented image and mask 250
# Saved augmented image and mask 251
# Saved augmented image and mask 252
# Saved augmented image and mask 253
# Saved augmented image and mask 254
# Saved augmented image and mask 255
# Saved augmented image and mask 256
# Saved augmented image and mask 257
# Saved augmented image and mask 258
# Saved augmented image and mask 259
# Saved augmented image and mask 260
# Saved augmented image and mask 261
# Saved augmented image and mask 262
# Saved augmented image and mask 263
# Saved augmented image and mask 264
# Saved augmented image and mask 265
# Saved augmented image and mask 266
# Saved augmented image and mask 267
# Saved augmented image and mask 268
# Saved augmented image and mask 269
# Saved augmented image and mask 270
# Saved augmented image and mask 271
# Saved augmented image and mask 272
# Saved augmented image and mask 273
# Saved augmented image and mask 274
# Saved augmented image and mask 275
# Saved augmented image and mask 276
# Saved augmented image and mask 277
# Saved augmented image and mask 278
# Saved augmented image and mask 279
# Saved augmented image and mask 280
# Saved augmented image and mask 281
# Saved augmented image and mask 282
# Saved augmented image and mask 283
# Saved augmented image and mask 284
# Saved augmented image and mask 285
# Saved augmented image and mask 286
# Saved augmented image and mask 287
# Saved augmented image and mask 288
# Saved augmented image and mask 289
# Saved augmented image and mask 290
# Saved augmented image and mask 291
# Saved augmented image and mask 292
# Saved augmented image and mask 293
# Saved augmented image and mask 294
# Saved augmented image and mask 295
# Saved augmented image and mask 296
# Saved augmented image and mask 297
# Saved augmented image and mask 298
# Saved augmented image and mask 299
# Saved augmented image and mask 300
# Saved augmented image and mask 301
# Saved augmented image and mask 302
# Saved augmented image and mask 303
# Saved augmented image and mask 304
# Saved augmented image and mask 305
# Saved augmented image and mask 306
# Saved augmented image and mask 307
# Saved augmented image and mask 308
# Saved augmented image and mask 309
# Saved augmented image and mask 310
# Saved augmented image and mask 311
# Saved augmented image and mask 312
# Saved augmented image and mask 313
# Saved augmented image and mask 314
# Saved augmented image and mask 315
# Saved augmented image and mask 316
# Saved augmented image and mask 317
# Saved augmented image and mask 318
# Saved augmented image and mask 319
# Saved augmented image and mask 320
# Saved augmented image and mask 321
# Saved augmented image and mask 322
# Saved augmented image and mask 323
# Saved augmented image and mask 324
# Saved augmented image and mask 325
# Saved augmented image and mask 326
# Saved augmented image and mask 327
# Saved augmented image and mask 328
# Saved augmented image and mask 329
# Saved augmented image and mask 330
# Saved augmented image and mask 331
# Saved augmented image and mask 332
# Saved augmented image and mask 333
# Saved augmented image and mask 334
# Saved augmented image and mask 335
# Saved augmented image and mask 336
# Saved augmented image and mask 337
# Saved augmented image and mask 338
# Saved augmented image and mask 339
# Saved augmented image and mask 340
# Saved augmented image and mask 341
# Saved augmented image and mask 342
# Saved augmented image and mask 343
# Saved augmented image and mask 344
# Saved augmented image and mask 345
# Saved augmented image and mask 346
# Saved augmented image and mask 347
# Saved augmented image and mask 348
# Saved augmented image and mask 349
# Saved augmented image and mask 350
# Saved augmented image and mask 351
# Saved augmented image and mask 352
# Saved augmented image and mask 353
# Saved augmented image and mask 354
# Saved augmented image and mask 355
# Saved augmented image and mask 356
# Saved augmented image and mask 357
# Saved augmented image and mask 358
# Saved augmented image and mask 359
# Saved augmented image and mask 360
# Saved augmented image and mask 361
# Saved augmented image and mask 362
# Saved augmented image and mask 363
# Saved augmented image and mask 364
# Saved augmented image and mask 365
# Saved augmented image and mask 366
# Saved augmented image and mask 367
# Saved augmented image and mask 368
# Saved augmented image and mask 369
# Saved augmented image and mask 370
# Saved augmented image and mask 371
# Saved augmented image and mask 372
# Saved augmented image and mask 373
# Saved augmented image and mask 374
# Saved augmented image and mask 375
# Saved augmented image and mask 376
# Saved augmented image and mask 377
# Saved augmented image and mask 378
# Saved augmented image and mask 379
# Saved augmented image and mask 380
# Saved augmented image and mask 381
# Saved augmented image and mask 382
# Saved augmented image and mask 383
# Saved augmented image and mask 384
# Saved augmented image and mask 385
# Saved augmented image and mask 386
# Saved augmented image and mask 387
# Saved augmented image and mask 388
# Saved augmented image and mask 389
# Saved augmented image and mask 390
# Saved augmented image and mask 391
# Saved augmented image and mask 392
# Saved augmented image and mask 393
# Saved augmented image and mask 394
# Saved augmented image and mask 395
# Saved augmented image and mask 396
# Saved augmented image and mask 397
# Saved augmented image and mask 398
# Saved augmented image and mask 399
# Saved augmented image and mask 400
# Saved augmented image and mask 401
# Saved augmented image and mask 402
# Saved augmented image and mask 403
# Saved augmented image and mask 404
# Saved augmented image and mask 405
# Saved augmented image and mask 406
# Saved augmented image and mask 407
# Saved augmented image and mask 408
# Saved augmented image and mask 409
# Saved augmented image and mask 410
# Saved augmented image and mask 411
# Saved augmented image and mask 412
# Saved augmented image and mask 413
# Saved augmented image and mask 414
# Saved augmented image and mask 415
# Saved augmented image and mask 416
# Saved augmented image and mask 417
# Saved augmented image and mask 418
# Saved augmented image and mask 419
# Saved augmented image and mask 420
# Saved augmented image and mask 421
# Saved augmented image and mask 422
# Saved augmented image and mask 423
# Saved augmented image and mask 424
# Saved augmented image and mask 425
# Saved augmented image and mask 426
# Saved augmented image and mask 427
# Saved augmented image and mask 428
# Saved augmented image and mask 429
# Saved augmented image and mask 430
# Saved augmented image and mask 431
# Saved augmented image and mask 432
# Saved augmented image and mask 433
# Saved augmented image and mask 434
# Saved augmented image and mask 435
# Saved augmented image and mask 436
# Saved augmented image and mask 437
# Saved augmented image and mask 438
# Saved augmented image and mask 439
# Saved augmented image and mask 440
# Saved augmented image and mask 441
# Saved augmented image and mask 442
# Saved augmented image and mask 443
# Saved augmented image and mask 444
# Saved augmented image and mask 445
# Saved augmented image and mask 446
# Saved augmented image and mask 447
# Saved augmented image and mask 448
# Saved augmented image and mask 449
# Saved augmented image and mask 450
# Saved augmented image and mask 451
# Saved augmented image and mask 452
# Saved augmented image and mask 453
# Saved augmented image and mask 454
# Saved augmented image and mask 455
# Saved augmented image and mask 456
# Saved augmented image and mask 457
# Saved augmented image and mask 458
# Saved augmented image and mask 459
# Saved augmented image and mask 460
# Saved augmented image and mask 461
# Saved augmented image and mask 462
# Saved augmented image and mask 463
# Saved augmented image and mask 464
# Saved augmented image and mask 465
# Saved augmented image and mask 466
# Saved augmented image and mask 467
# Saved augmented image and mask 468
# Saved augmented image and mask 469
# Saved augmented image and mask 470
# Saved augmented image and mask 471
# Saved augmented image and mask 472
# Saved augmented image and mask 473
# Saved augmented image and mask 474
# Saved augmented image and mask 475
# Saved augmented image and mask 476
# Saved augmented image and mask 477
# Saved augmented image and mask 478
# Saved augmented image and mask 479
# Saved augmented image and mask 480
# Saved augmented image and mask 481
# Saved augmented image and mask 482
# Saved augmented image and mask 483
# Saved augmented image and mask 484
# Saved augmented image and mask 485
# Saved augmented image and mask 486
# Saved augmented image and mask 487
# Saved augmented image and mask 488
# Saved augmented image and mask 489
# Saved augmented image and mask 490
# Saved augmented image and mask 491
# Saved augmented image and mask 492
# Saved augmented image and mask 493
# Saved augmented image and mask 494
# Saved augmented image and mask 495
# Saved augmented image and mask 496
# Saved augmented image and mask 497
# Saved augmented image and mask 498
# Saved augmented image and mask 499
# Saved augmented image and mask 500
# Saved augmented image and mask 501
# Saved augmented image and mask 502
# Saved augmented image and mask 503
# Saved augmented image and mask 504
# Saved augmented image and mask 505
# Saved augmented image and mask 506
# Saved augmented image and mask 507
# Saved augmented image and mask 508
# Saved augmented image and mask 509
# Saved augmented image and mask 510
# Saved augmented image and mask 511
# Saved augmented image and mask 512
# Saved augmented image and mask 513
# Saved augmented image and mask 514
# Saved augmented image and mask 515
# Saved augmented image and mask 516
# Saved augmented image and mask 517
# Saved augmented image and mask 518
# Saved augmented image and mask 519
# Saved augmented image and mask 520
# Saved augmented image and mask 521
# Saved augmented image and mask 522
# Saved augmented image and mask 523
# Saved augmented image and mask 524
# Saved augmented image and mask 525
# Saved augmented image and mask 526
# Saved augmented image and mask 527
# Saved augmented image and mask 528
# Saved augmented image and mask 529
# Saved augmented image and mask 530
# Saved augmented image and mask 531
# Saved augmented image and mask 532
# Saved augmented image and mask 533
# Saved augmented image and mask 534
# Saved augmented image and mask 535
# Saved augmented image and mask 536
# Saved augmented image and mask 537
# Saved augmented image and mask 538
# Saved augmented image and mask 539
# Saved augmented image and mask 540
# Saved augmented image and mask 541
# Saved augmented image and mask 542
# Saved augmented image and mask 543
# Saved augmented image and mask 544
# Saved augmented image and mask 545
# Saved augmented image and mask 546
# Saved augmented image and mask 547
# Saved augmented image and mask 548
# Saved augmented image and mask 549
# Saved augmented image and mask 550
# Saved augmented image and mask 551
# Saved augmented image and mask 552
# Saved augmented image and mask 553
# Saved augmented image and mask 554
# Saved augmented image and mask 555
# Saved augmented image and mask 556
# Saved augmented image and mask 557
# Saved augmented image and mask 558
# Saved augmented image and mask 559
# Saved augmented image and mask 560
# Saved augmented image and mask 561
# Saved augmented image and mask 562
# Saved augmented image and mask 563
# Saved augmented image and mask 564
# Saved augmented image and mask 565
# Saved augmented image and mask 566
# Saved augmented image and mask 567
# Saved augmented image and mask 568
# Saved augmented image and mask 569
# Saved augmented image and mask 570
# Saved augmented image and mask 571
# Saved augmented image and mask 572
# Saved augmented image and mask 573
# Saved augmented image and mask 574
# Saved augmented image and mask 575
# Saved augmented image and mask 576
# Saved augmented image and mask 577
# Saved augmented image and mask 578
# Saved augmented image and mask 579
# Saved augmented image and mask 580
# Saved augmented image and mask 581
# Saved augmented image and mask 582
# Saved augmented image and mask 583
# Saved augmented image and mask 584
# Saved augmented image and mask 585
# Saved augmented image and mask 586
# Saved augmented image and mask 587
# Saved augmented image and mask 588
# Saved augmented image and mask 589
# Saved augmented image and mask 590
# Saved augmented image and mask 591
# Saved augmented image and mask 592
# Saved augmented image and mask 593
# Saved augmented image and mask 594
# Saved augmented image and mask 595
# Saved augmented image and mask 596
# Saved augmented image and mask 597
# Saved augmented image and mask 598
# Saved augmented image and mask 599
# Saved augmented image and mask 600
# Saved augmented image and mask 601
# Saved augmented image and mask 602
# Saved augmented image and mask 603
# Saved augmented image and mask 604
# Saved augmented image and mask 605
# Saved augmented image and mask 606
# Saved augmented image and mask 607
# Saved augmented image and mask 608
# Saved augmented image and mask 609
# Saved augmented image and mask 610
# Saved augmented image and mask 611
# Saved augmented image and mask 612
# Saved augmented image and mask 613
# Saved augmented image and mask 614
# Saved augmented image and mask 615
# Saved augmented image and mask 616
# Saved augmented image and mask 617
# Saved augmented image and mask 618
# Saved augmented image and mask 619
# Saved augmented image and mask 620
# Saved augmented image and mask 621
# Saved augmented image and mask 622
# Saved augmented image and mask 623
# Saved augmented image and mask 624
# Saved augmented image and mask 625
# Saved augmented image and mask 626
# Saved augmented image and mask 627
# Saved augmented image and mask 628
# Saved augmented image and mask 629
# Saved augmented image and mask 630
# Saved augmented image and mask 631
# Saved augmented image and mask 632
# Saved augmented image and mask 633
# Saved augmented image and mask 634
# Saved augmented image and mask 635
# Saved augmented image and mask 636
# Saved augmented image and mask 637
# Saved augmented image and mask 638
# Saved augmented image and mask 639
# Saved augmented image and mask 640
# Saved augmented image and mask 641
# Saved augmented image and mask 642
# Saved augmented image and mask 643
# Saved augmented image and mask 644
# Saved augmented image and mask 645
# Saved augmented image and mask 646
# Saved augmented image and mask 647
# Saved augmented image and mask 648
# Saved augmented image and mask 649
# Saved augmented image and mask 650
# Saved augmented image and mask 651
# Saved augmented image and mask 652
# Saved augmented image and mask 653
# Saved augmented image and mask 654
# Saved augmented image and mask 655
# Saved augmented image and mask 656
# Saved augmented image and mask 657
# Saved augmented image and mask 658
# Saved augmented image and mask 659
# Saved augmented image and mask 660
# Saved augmented image and mask 661
# Saved augmented image and mask 662
# Saved augmented image and mask 663
# Saved augmented image and mask 664
# Saved augmented image and mask 665
# Saved augmented image and mask 666
# Saved augmented image and mask 667
# Saved augmented image and mask 668
# Saved augmented image and mask 669
# Saved augmented image and mask 670
# Saved augmented image and mask 671
# Saved augmented image and mask 672
# Saved augmented image and mask 673
# Saved augmented image and mask 674
# Saved augmented image and mask 675
# Saved augmented image and mask 676
# Saved augmented image and mask 677
# Saved augmented image and mask 678
# Saved augmented image and mask 679
# Saved augmented image and mask 680
# Saved augmented image and mask 681
# Saved augmented image and mask 682
# Saved augmented image and mask 683
# Saved augmented image and mask 684
# Saved augmented image and mask 685
# Saved augmented image and mask 686
# Saved augmented image and mask 687
# Saved augmented image and mask 688
# Saved augmented image and mask 689
# Saved augmented image and mask 690
# Saved augmented image and mask 691
# Saved augmented image and mask 692
# Saved augmented image and mask 693
# Saved augmented image and mask 694
# Saved augmented image and mask 695
# Saved augmented image and mask 696
# Saved augmented image and mask 697
# Saved augmented image and mask 698
# Saved augmented image and mask 699
# Saved augmented image and mask 700
# Saved augmented image and mask 701
# Saved augmented image and mask 702
# Saved augmented image and mask 703
# Saved augmented image and mask 704
# Saved augmented image and mask 705
# Saved augmented image and mask 706
# Saved augmented image and mask 707
# Saved augmented image and mask 708
# Saved augmented image and mask 709
# Saved augmented image and mask 710
# Saved augmented image and mask 711
# Saved augmented image and mask 712
# Saved augmented image and mask 713
# Saved augmented image and mask 714
# Saved augmented image and mask 715
# Saved augmented image and mask 716
# Saved augmented image and mask 717
# Saved augmented image and mask 718
# Saved augmented image and mask 719
# Saved augmented image and mask 720
# Saved augmented image and mask 721
# Saved augmented image and mask 722
# Saved augmented image and mask 723
# Saved augmented image and mask 724
# Saved augmented image and mask 725
# Saved augmented image and mask 726
# Saved augmented image and mask 727
# Saved augmented image and mask 728
# Saved augmented image and mask 729
# Saved augmented image and mask 730
# Saved augmented image and mask 731
# Saved augmented image and mask 732
# Saved augmented image and mask 733
# Saved augmented image and mask 734
# Saved augmented image and mask 735
# Saved augmented image and mask 736
# Saved augmented image and mask 737
# Saved augmented image and mask 738
# Saved augmented image and mask 739
# Saved augmented image and mask 740
# Saved augmented image and mask 741
# Saved augmented image and mask 742
# Saved augmented image and mask 743
# Saved augmented image and mask 744
# Saved augmented image and mask 745
# Saved augmented image and mask 746
